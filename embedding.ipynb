# %%
pip install openai==0.28.0
# Out:
# Requirement already satisfied: openai==0.28.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (4.67.1)
# Requirement already satisfied: aiohttp in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (3.11.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.18.3)
# Requirement already satisfied: colorama in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from tqdm->openai==0.28.0) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai

# Set your OpenAI API key
openai.api_key = "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"

# %%
import os

# %%
def fetch_json_directories(base_dir):
    """
    Recursively fetch directories containing .json files in the given directory.

    Args:
        base_dir (str): The base directory to search within.

    Returns:
        list: A list of unique directories containing .json files.
    """
    json_directories = set()  # Use a set to ensure uniqueness
    
    # Walk through all directories and subdirectories
    for root, _, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".json"):  # Check for .json extension
                json_directories.add(root)  # Add the directory to the set
                break  # No need to check other files in this directory
    
    return list(json_directories)

# %%
legal_case_paths = fetch_json_directories("C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/")

# %%
len(legal_case_paths)
# Out:
# 540

# %%
legal_case_paths
# Out:
# ['C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\66.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\146.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\178.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\7.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\117.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\23.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\66.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\67.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\24.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\102.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\42.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\15.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\64.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\13.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\160.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\184.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\56.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\37.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\121.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\152.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\200.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\232.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\67.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\83.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\134.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\113.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\31.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\169.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\177.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\221.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\242.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\118.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\114.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\205.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\39.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\14.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\95.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\179.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\145.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\88.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\172.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\2.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\24.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\154.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\139.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\8.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\115.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\90.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\8.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\7.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\61.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\168.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\101.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\202.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\108.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\25.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\62.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\79.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\206.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\153.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\16.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\133.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\147.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\41.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\189.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\20.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\16.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\117.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\224.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\29.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\210.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\57.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\123.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\27.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\128.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\130.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\119.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\114.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\42.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\121.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\202.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\216.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\111.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\96.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\175.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\101.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\162.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\97.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\133.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\8.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\24.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\240.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\23.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\5.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\98.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\131.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\165.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\3.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\2.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\198.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\225.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\61.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\51.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\14.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\5.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\192.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\16.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\230.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\90.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\226.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\239.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\222.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\239.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\35.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\139.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\106.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\158.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\233.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\98.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\104.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\231.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\129.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\85.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\44.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\237.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\18.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\30.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\78.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\53.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\240.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\4.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\118.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\153.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\181.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\182.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\28.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\180.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\176.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\86.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\2.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\87.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\1.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\122.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\162.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\20.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\193.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\21.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\241.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\197.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\211.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\43.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\6.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\223.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\31.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\49.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\198.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\105.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\112.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\220.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\105.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\193.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\38.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\161.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\68.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\38.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\21.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\214.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\11.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\7.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\75.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\167.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\187.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\218.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\151.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\194.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\10.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\171.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\48.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\107.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\21.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\147.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\241.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\135.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\89.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\9.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\18.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\92.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\140.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\181.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\33.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\77.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\113.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\102.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\140.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\148.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\107.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\33.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\100.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\71.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\216.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\228.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\174.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\182.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\151.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\50.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\126.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\99.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\141.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\232.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\213.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\55.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\26.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\165.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\187.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\103.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\131.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\109.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\129.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\207.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\22.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\167.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\237.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\97.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\91.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\159.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\64.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\163.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\233.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\11.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\1.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\15.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\168.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\81.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\24.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\4.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\69.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\155.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\53.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\79.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\116.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\227.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\184.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\22.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\2.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\177.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\106.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\110.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\203.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\50.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\124.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\231.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\55.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\104.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\3.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\70.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\19.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\132.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\227.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\219.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\212.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\99.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\180.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\196.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\88.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\76.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\221.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\217.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\1.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\27.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\183.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\103.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\192.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\40.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\195.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\116.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\1.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\119.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\207.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\225.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\126.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\27.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\170.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\59.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\7.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\230.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\46.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\3.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\60.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\120.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\190.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\36.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\13.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\84.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\57.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\82.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\141.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\154.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\127.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\26.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\17.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\226.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\155.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\25.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\72.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\201.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\236.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\17.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\149.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\185.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\60.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\209.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\166.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\71.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\172.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\22.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\235.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\6.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\86.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\136.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\39.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\13.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\9.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\190.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\41.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\137.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\110.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\10.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\63.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\166.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\77.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\171.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\108.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\49.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\199.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\48.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\186.zip_extracted\\metadata',
# ...
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\146.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\34.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\82.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\170.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\111.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\134.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\58.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\208.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\188.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\73.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\125.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\143.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\169.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\16.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\37.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\135.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\130.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\144.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\173.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\10.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\176.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\138.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\11.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\208.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\52.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\178.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\186.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\109.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\15.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\174.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\25.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\175.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\224.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\128.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\215.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\93.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\84.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\15.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\9.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\214.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\124.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\44.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\123.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\68.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\242.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\58.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\203.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\4.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\26.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\137.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\35.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\27.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\14.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\52.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\206.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\14.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\21.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\32.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\223.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\210.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\59.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\9.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\30.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\18.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\204.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\229.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\23.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\218.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\26.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\5.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\145.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\120.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\161.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\25.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\136.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\75.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\47.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\125.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\69.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\12.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\47.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\45.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\17.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\94.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\20.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\87.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\235.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\201.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\96.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\65.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\8.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\159.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\34.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\13.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\156.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\185.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\12.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\17.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\40.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\76.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\6.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\215.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\238.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\149.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\46.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\6.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\191.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\10.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\12.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\152.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\74.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\54.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\179.zip_extracted\\metadata']

# %%
import faiss
import numpy as np
import openai
import json
import pickle
from pathlib import Path
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity

openai.api_key = "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"

def split_into_chunks(text, chunk_size=1000, chunk_overlap=200):
    """
    Splits the text into chunks of specified size with overlap.

    Parameters:
    - text: The input text to be split.
    - chunk_size: The maximum size of each chunk (default: 1000).
    - chunk_overlap: The overlap size between consecutive chunks (default: 200).

    Returns:
    - List of text chunks.
    """
    chunks = []
    for i in range(0, len(text), chunk_size - chunk_overlap):
        chunks.append(text[i:i + chunk_size])
    return chunks

def load_json_files(directory):
    """
    Loads and extracts content from JSON files in the specified directory.

    Parameters:
    - directory: Path to the directory containing JSON files.

    Returns:
    - List of dictionaries with 'id' and 'content' for each JSON.
    """
    data = []
    directory = Path(directory)
    for file in tqdm(directory.rglob("*.json"), desc="Loading JSON files"):
        try:
            with open(file, "r", encoding="utf-8") as f:
                json_data = json.load(f)
                if isinstance(json_data, dict):
                    content = json.dumps(json_data)  # Convert dict to string
                elif isinstance(json_data, list):
                    content = "\n".join([json.dumps(item) for item in json_data])
                else:
                    content = str(json_data)
            data.append({
                "id": f"{os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(file))))}_{os.path.basename(os.path.dirname(os.path.dirname(file)))}_{os.path.basename(os.path.dirname(file))}_{file.name}",
                "content": content
            })
        except Exception as e:
            print(f"Error loading file {file.name}: {e}")
            continue
    return data

def process_json_files(json_files):
    """
    Processes JSON files to extract content and split it into chunks.

    Parameters:
    - json_files: List of dictionaries with 'id' and 'content' for each JSON.

    Returns:
    - List of dictionaries containing 'id' and 'text_chunk'.
    """
    all_chunks = []
    for json_file in tqdm(json_files, desc="Processing JSON files"):
        # Split JSON content into chunks
        text_chunks = split_into_chunks(json_file["content"])
        # Append text chunks with their corresponding IDs
        for i, chunk in enumerate(text_chunks):
            all_chunks.append({
                "id": f"{json_file['id']}_chunk_{i}",
                "text_chunk": chunk
            })
    return all_chunks

def generate_embeddings_from_chunks(chunks, batch_size=2):
    """
    Generates embeddings for the given text chunks using OpenAI's Embedding API.

    Parameters:
    - chunks: List of dictionaries with 'id' and 'text_chunk'.
    - batch_size: Number of chunks to process in a single API call (default: 2).

    Returns:
    - List of embeddings with their corresponding 'id'.
    """
    embeddings = []
    for i in tqdm(range(0, len(chunks), batch_size), desc="Generating embeddings"):
        batch = chunks[i:i + batch_size]
        try:
            # Extract text content for embedding generation
            batch_texts = [item["text_chunk"] for item in batch]
            response = openai.Embedding.create(
                model="text-embedding-ada-002",
                input=batch_texts
            )
            # Add embeddings with corresponding IDs
            for j, embedding in enumerate(response["data"]):
                embeddings.append({
                    "id": batch[j]["id"],
                    "embedding": embedding["embedding"]
                })
        except Exception as e:
            print(f"Error generating embedding for batch {i}: {e}")
            continue
    return embeddings

def save_embeddings(embeddings, file_name="embeddings.pkl"):
    """
    Saves embeddings to a pickle file.

    Parameters:
    - embeddings: List of embeddings to save.
    - file_name: Name of the file to save the embeddings (default: 'embeddings.pkl').
    """
    try:
        with open(file_name, "wb") as f:
            pickle.dump(embeddings, f)
        print(f"Embeddings saved to {file_name}")
    except Exception as e:
        print(f"Error saving embeddings: {e}")

def store_embeddings_in_faiss(embeddings, faiss_index_file="faiss_index.index", d=1536):
    """
    Stores embeddings in a FAISS vector database.

    Parameters:
    - embeddings: List of dictionaries containing 'id' and 'embedding'.
    - faiss_index_file: File name to save the FAISS index (default: 'faiss_index.index').
    - d: Dimension of the embeddings (default: 1536 for OpenAI embeddings).
    """
    # Initialize a FAISS index (L2 distance for default)
    index = faiss.IndexFlatL2(d)

    # Metadata mapping for IDs
    id_mapping = []

    # Convert embeddings into a NumPy array
    vectors = []
    for item in embeddings:
        id_mapping.append(item["id"])
        vectors.append(np.array(item["embedding"], dtype=np.float32))

    vectors = np.vstack(vectors)  # Stack vectors into a single NumPy array

    # Add vectors to the FAISS index
    index.add(vectors)

    # Save the FAISS index
    faiss.write_index(index, faiss_index_file)

    # Save the ID mapping
    with open("id_mapping.pkl", "wb") as f:
        pickle.dump(id_mapping, f)

    print(f"Stored {len(embeddings)} embeddings into the FAISS index.")

if __name__ == "__main__":
    # Directory containing JSON files
    json_dir = "C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/"  # Replace with your directory path

    # Load JSON files
    json_files=[]
    for folder in legal_case_paths:
        folder_files = load_json_files(folder)
        json_files.extend(folder_files)
    print(len(json_files))
    # Process JSON files to generate text chunks (content_dict)
    try:
        content_dict = process_json_files(json_files)
        print(f"Processed {len(content_dict)} text chunks.")
    except Exception as e:
        print(f"Error during processing: {e}")

    # Save content_dict to a file for later use
    try:
        with open("content_dict.pkl", "wb") as f:
            pickle.dump(content_dict, f)
        print("Saved content_dict with text chunks.")
    except Exception as e:
        print(f"Error saving content_dict: {e}")

    # Generate embeddings from text chunks
    try:
        embeddings = generate_embeddings_from_chunks(content_dict, batch_size=2)
        print(f"Generated embeddings for {len(embeddings)} chunks.")
    except Exception as e:
        print(f"Error generating embeddings: {e}")

    # Save embeddings to a file
    save_embeddings(embeddings, file_name="output_embeddings.pkl")

    # Store embeddings in FAISS
    try:
        store_embeddings_in_faiss(embeddings, faiss_index_file="faiss_index.index", d=1536)
        print("Embeddings successfully stored in FAISS.")
    except Exception as e:
        print(f"Error storing embeddings in FAISS: {e}")
# Out:
# Loading JSON files: 2it [00:00, 50.74it/s]
# Loading JSON files: 2it [00:00, 30.67it/s]
# Loading JSON files: 113it [00:01, 58.24it/s]
# Loading JSON files: 81it [00:01, 78.31it/s]
# Loading JSON files: 2it [00:00, 50.88it/s]
# Loading JSON files: 170it [00:02, 74.37it/s]
# Loading JSON files: 51it [00:00, 83.92it/s]
# Loading JSON files: 49it [00:00, 56.70it/s]
# Loading JSON files: 160it [00:02, 70.74it/s]
# Loading JSON files: 2it [00:00, 10.32it/s]
# Loading JSON files: 70it [00:01, 65.57it/s]
# Loading JSON files: 2it [00:00, 56.64it/s]
# Loading JSON files: 54it [00:00, 68.51it/s]
# Loading JSON files: 2it [00:00, 46.61it/s]
# Loading JSON files: 116it [00:01, 59.76it/s]
# Loading JSON files: 94it [00:01, 71.00it/s]
# Loading JSON files: 82it [00:01, 74.95it/s]
# Loading JSON files: 76it [00:01, 73.57it/s]
# Loading JSON files: 166it [00:02, 81.70it/s]
# Loading JSON files: 115it [00:01, 75.18it/s]
# Loading JSON files: 88it [00:01, 77.04it/s]
# Loading JSON files: 2it [00:00, 26.89it/s]
# Loading JSON files: 2it [00:00, 60.20it/s]
# Loading JSON files: 81it [00:01, 76.31it/s]
# Loading JSON files: 2it [00:00, 48.54it/s]
# Loading JSON files: 2it [00:00, 40.08it/s]
# Loading JSON files: 69it [00:00, 82.26it/s]
# Loading JSON files: 2it [00:00, 38.77it/s]
# Loading JSON files: 121it [00:01, 75.93it/s]
# Loading JSON files: 2it [00:00, 40.36it/s]
# Loading JSON files: 2it [00:00, 40.71it/s]
# Loading JSON files: 2it [00:00, 48.61it/s]
# Loading JSON files: 2it [00:00, 48.60it/s]
# Loading JSON files: 2it [00:00, 40.51it/s]
# Loading JSON files: 2it [00:00, 61.63it/s]
# Loading JSON files: 2it [00:00, 48.71it/s]
# Loading JSON files: 2it [00:00, 60.59it/s]
# Loading JSON files: 99it [00:01, 78.02it/s]
# Loading JSON files: 2it [00:00, 49.02it/s]
# Loading JSON files: 62it [00:00, 64.82it/s]
# Loading JSON files: 118it [00:01, 82.68it/s]
# Loading JSON files: 2it [00:00, 48.82it/s]
# Loading JSON files: 2it [00:00, 60.48it/s]
# Loading JSON files: 118it [00:01, 85.38it/s]
# Loading JSON files: 2it [00:00, 49.63it/s]
# Loading JSON files: 106it [00:01, 90.86it/s]
# Loading JSON files: 156it [00:01, 86.67it/s]
# Loading JSON files: 2it [00:00, 49.09it/s]
# Loading JSON files: 2it [00:00, 61.44it/s]
# Loading JSON files: 2it [00:00, 41.22it/s]
# Loading JSON files: 73it [00:00, 74.51it/s]
# Loading JSON files: 2it [00:00, 40.75it/s]
# Loading JSON files: 139it [00:01, 81.71it/s]
# Loading JSON files: 95it [00:01, 77.37it/s]
# Loading JSON files: 192it [00:02, 80.11it/s]
# Loading JSON files: 2it [00:00, 61.24it/s]
# Loading JSON files: 60it [00:00, 73.41it/s]
# Loading JSON files: 73it [00:00, 90.99it/s]
# Loading JSON files: 84it [00:00, 86.11it/s]
# Loading JSON files: 2it [00:00, 39.90it/s]
# Loading JSON files: 2it [00:00, 24.28it/s]
# Loading JSON files: 127it [00:01, 84.64it/s]
# Loading JSON files: 118it [00:01, 81.84it/s]
# Loading JSON files: 67it [00:00, 84.74it/s]
# Loading JSON files: 2it [00:00, 39.97it/s]
# Loading JSON files: 2it [00:00, 61.71it/s]
# Loading JSON files: 72it [00:00, 83.74it/s]
# Loading JSON files: 157it [00:01, 82.28it/s]
# Loading JSON files: 2it [00:00, 38.55it/s]
# Loading JSON files: 2it [00:00, 80.56it/s]
# Loading JSON files: 2it [00:00, 19.89it/s]
# Loading JSON files: 2it [00:00, 60.03it/s]
# Loading JSON files: 2it [00:00, 44.53it/s]
# Loading JSON files: 2it [00:00, 30.33it/s]
# Loading JSON files: 149it [00:01, 75.30it/s]
# Loading JSON files: 2it [00:00, 30.02it/s]
# Loading JSON files: 157it [00:01, 80.99it/s]
# Loading JSON files: 144it [00:01, 86.44it/s]
# Loading JSON files: 2it [00:00, 63.70it/s]
# Loading JSON files: 2it [00:00, 50.82it/s]
# Loading JSON files: 2it [00:00, 46.59it/s]
# Loading JSON files: 2it [00:00, 44.16it/s]
# Loading JSON files: 177it [00:02, 82.25it/s]
# Loading JSON files: 2it [00:00, 57.86it/s]
# Loading JSON files: 102it [00:01, 84.24it/s]
# Loading JSON files: 2it [00:00, 51.30it/s]
# Loading JSON files: 125it [00:01, 74.73it/s]
# Loading JSON files: 84it [00:01, 74.92it/s]
# Loading JSON files: 2it [00:00, 40.08it/s]
# Loading JSON files: 151it [00:02, 75.45it/s]
# Loading JSON files: 2it [00:00, 56.40it/s]
# Loading JSON files: 2it [00:00, 27.75it/s]
# Loading JSON files: 76it [00:00, 89.43it/s]
# Loading JSON files: 148it [00:01, 86.17it/s]
# Loading JSON files: 2it [00:00, 65.73it/s]
# Loading JSON files: 2it [00:00, 52.15it/s]
# Loading JSON files: 2it [00:00, 48.09it/s]
# Loading JSON files: 110it [00:01, 84.99it/s]
# Loading JSON files: 2it [00:00, 46.77it/s]
# Loading JSON files: 93it [00:01, 77.27it/s]
# Loading JSON files: 2it [00:00, 37.41it/s]
# Loading JSON files: 2it [00:00, 59.89it/s]
# Loading JSON files: 59it [00:00, 80.83it/s]
# Loading JSON files: 182it [00:02, 89.92it/s]
# Loading JSON files: 2it [00:00, 45.85it/s]
# Loading JSON files: 96it [00:01, 80.48it/s]
# Loading JSON files: 173it [00:02, 82.67it/s]
# Loading JSON files: 2it [00:00, 50.59it/s]
# Loading JSON files: 68it [00:00, 71.89it/s]
# Loading JSON files: 95it [00:01, 85.06it/s]
# Loading JSON files: 2it [00:00, 49.94it/s]
# Loading JSON files: 2it [00:00, 42.41it/s]
# Loading JSON files: 78it [00:00, 79.69it/s]
# Loading JSON files: 2it [00:00, 60.48it/s]
# Loading JSON files: 114it [00:01, 78.45it/s]
# Loading JSON files: 2it [00:00, 44.88it/s]
# Loading JSON files: 128it [00:01, 81.07it/s]
# Loading JSON files: 76it [00:00, 81.67it/s]
# Loading JSON files: 66it [00:00, 82.55it/s]
# Loading JSON files: 2it [00:00, 43.63it/s]
# Loading JSON files: 2it [00:00, 42.98it/s]
# Loading JSON files: 2it [00:00, 36.38it/s]
# Loading JSON files: 2it [00:00, 56.61it/s]
# Loading JSON files: 71it [00:00, 77.49it/s]
# Loading JSON files: 77it [00:01, 75.00it/s]
# Loading JSON files: 2it [00:00, 51.75it/s]
# Loading JSON files: 2it [00:00, 51.23it/s]
# Loading JSON files: 2it [00:00, 59.66it/s]
# Loading JSON files: 61it [00:00, 77.64it/s]
# Loading JSON files: 87it [00:01, 80.64it/s]
# Loading JSON files: 149it [00:01, 81.07it/s]
# Loading JSON files: 145it [00:01, 77.25it/s]
# Loading JSON files: 131it [00:01, 81.64it/s]
# Loading JSON files: 113it [00:01, 86.31it/s]
# Loading JSON files: 2it [00:00, 44.02it/s]
# Loading JSON files: 82it [00:01, 81.00it/s]
# Loading JSON files: 101it [00:01, 82.18it/s]
# Loading JSON files: 112it [00:01, 86.26it/s]
# Loading JSON files: 64it [00:00, 92.72it/s]
# Loading JSON files: 163it [00:01, 91.34it/s]
# Loading JSON files: 2it [00:00, 63.90it/s]
# Loading JSON files: 2it [00:00, 60.81it/s]
# Loading JSON files: 2it [00:00, 45.27it/s]
# Loading JSON files: 2it [00:00, 42.71it/s]
# Loading JSON files: 2it [00:00, 53.93it/s]
# Loading JSON files: 2it [00:00, 45.26it/s]
# Loading JSON files: 2it [00:00, 41.43it/s]
# Loading JSON files: 2it [00:00, 39.84it/s]
# Loading JSON files: 90it [00:01, 81.08it/s]
# Loading JSON files: 76it [00:00, 79.23it/s]
# Loading JSON files: 68it [00:00, 84.00it/s]
# Loading JSON files: 105it [00:01, 89.60it/s]
# Loading JSON files: 2it [00:00, 42.89it/s]
# Loading JSON files: 2it [00:00, 63.22it/s]
# Loading JSON files: 2it [00:00, 17.60it/s]
# Loading JSON files: 2it [00:00, 40.07it/s]
# Loading JSON files: 2it [00:00, 53.66it/s]
# Loading JSON files: 2it [00:00, 42.56it/s]
# Loading JSON files: 76it [00:00, 83.08it/s]
# Loading JSON files: 160it [00:01, 85.23it/s]
# Loading JSON files: 82it [00:01, 81.48it/s]
# Loading JSON files: 72it [00:00, 79.44it/s]
# Loading JSON files: 129it [00:01, 78.14it/s]
# Loading JSON files: 2it [00:00, 55.90it/s]
# Loading JSON files: 2it [00:00, 54.21it/s]
# Loading JSON files: 2it [00:00, 58.20it/s]
# Loading JSON files: 92it [00:01, 78.51it/s]
# Loading JSON files: 2it [00:00, 58.04it/s]
# Loading JSON files: 2it [00:00, 53.60it/s]
# Loading JSON files: 2it [00:00, 65.37it/s]
# Loading JSON files: 2it [00:00, 44.42it/s]
# Loading JSON files: 100it [00:01, 79.11it/s]
# Loading JSON files: 2it [00:00, 39.68it/s]
# Loading JSON files: 134it [00:01, 76.30it/s]
# Loading JSON files: 78it [00:01, 77.48it/s]
# Loading JSON files: 148it [00:01, 84.83it/s]
# Loading JSON files: 2it [00:00, 50.44it/s]
# Loading JSON files: 61it [00:00, 87.89it/s]
# Loading JSON files: 2it [00:00, 47.80it/s]
# Loading JSON files: 4544it [00:44, 102.72it/s]
# Loading JSON files: 168it [00:00, 1835.58it/s]
# Loading JSON files: 2it [00:00, 40.35it/s]
# Loading JSON files: 74it [00:00, 75.63it/s]
# Loading JSON files: 2it [00:00, 44.96it/s]
# Loading JSON files: 88it [00:01, 71.64it/s]
# Loading JSON files: 2it [00:00, 61.53it/s]
# Loading JSON files: 2it [00:00, 88.93it/s]
# Loading JSON files: 2it [00:00, 58.84it/s]
# Loading JSON files: 118it [00:01, 78.85it/s]
# Loading JSON files: 2it [00:00, 38.21it/s]
# Loading JSON files: 73it [00:00, 78.26it/s]
# Loading JSON files: 2it [00:00, 60.74it/s]
# Loading JSON files: 155it [00:01, 79.72it/s]
# Loading JSON files: 145it [00:01, 80.33it/s]
# Loading JSON files: 24179it [05:09, 78.20it/s]
# Loading JSON files: 2it [00:00, 62.23it/s]
# Loading JSON files: 2it [00:00, 46.52it/s]
# Loading JSON files: 169it [00:01, 86.48it/s]
# Loading JSON files: 2it [00:00, 598.33it/s]
# Loading JSON files: 2it [00:00, 54.50it/s]
# Loading JSON files: 76it [00:00, 2214.60it/s]
# Loading JSON files: 72it [00:00, 1299.92it/s]
# Loading JSON files: 2it [00:00, 80.45it/s]
# Loading JSON files: 2it [00:00, 122.89it/s]
# Loading JSON files: 104it [00:00, 1040.83it/s]
# Loading JSON files: 2it [00:00, 90.04it/s]
# Loading JSON files: 66it [00:00, 2384.75it/s]
# Loading JSON files: 2it [00:00, 42.04it/s]
# Loading JSON files: 2it [00:00, 237.36it/s]
# Loading JSON files: 98it [00:01, 82.24it/s]
# Loading JSON files: 86it [00:00, 1436.00it/s]
# Loading JSON files: 80it [00:00, 815.60it/s]
# Loading JSON files: 2it [00:00, 160.20it/s]
# Loading JSON files: 86it [00:00, 1855.71it/s]
# Loading JSON files: 110it [00:00, 1036.83it/s]
# Loading JSON files: 2it [00:00, 71.48it/s]
# Loading JSON files: 2it [00:00, 51.56it/s]
# Loading JSON files: 145it [00:02, 68.31it/s]
# Loading JSON files: 2it [00:00, 43.64it/s]
# Loading JSON files: 137it [00:01, 83.96it/s]
# Loading JSON files: 71it [00:00, 929.33it/s]
# Loading JSON files: 2it [00:00, 53.86it/s]
# Loading JSON files: 114it [00:01, 76.30it/s]
# Loading JSON files: 2it [00:00, 71.78it/s]
# Loading JSON files: 2it [00:00, 207.46it/s]
# Loading JSON files: 69it [00:00, 2064.08it/s]
# Loading JSON files: 116it [00:01, 80.96it/s]
# Loading JSON files: 2it [00:00, 233.19it/s]
# Loading JSON files: 2it [00:00, 42.97it/s]
# Loading JSON files: 2it [00:00, 68.12it/s]
# Loading JSON files: 165it [00:01, 87.41it/s]
# Loading JSON files: 55it [00:00, 85.61it/s]
# Loading JSON files: 194it [00:02, 83.08it/s]
# Loading JSON files: 121it [00:01, 117.81it/s]
# Loading JSON files: 2it [00:00, 258.61it/s]
# Loading JSON files: 84it [00:00, 1353.87it/s]
# Loading JSON files: 2it [00:00, 47.42it/s]
# Loading JSON files: 2it [00:00, 222.99it/s]
# Loading JSON files: 121it [00:01, 82.34it/s]
# Loading JSON files: 2it [00:00, 305.95it/s]
# Loading JSON files: 2it [00:00, 195.77it/s]
# Loading JSON files: 162it [00:01, 82.29it/s]
# Loading JSON files: 87it [00:00, 1009.12it/s]
# Loading JSON files: 2it [00:00, 66.63it/s]
# Loading JSON files: 2it [00:00, 214.33it/s]
# Loading JSON files: 119it [00:00, 1187.21it/s]
# Loading JSON files: 2it [00:00, 60.95it/s]
# Loading JSON files: 157it [00:01, 85.67it/s]
# Loading JSON files: 174it [00:02, 84.03it/s]
# Loading JSON files: 92it [00:00, 1087.35it/s]
# Loading JSON files: 2it [00:00, 315.49it/s]
# Loading JSON files: 161it [00:01, 90.33it/s]
# Loading JSON files: 89it [00:00, 1034.98it/s]
# Loading JSON files: 76it [00:00, 2408.50it/s]
# Loading JSON files: 158it [00:01, 88.53it/s]
# Loading JSON files: 149it [00:01, 85.76it/s]
# Loading JSON files: 2it [00:00, 242.83it/s]
# Loading JSON files: 190it [00:02, 88.74it/s]
# Loading JSON files: 2it [00:00, 53.51it/s]
# Loading JSON files: 2it [00:00, 84.22it/s]
# Loading JSON files: 2it [00:00, 91.48it/s]
# Loading JSON files: 81it [00:00, 886.47it/s]
# Loading JSON files: 69it [00:00, 2198.51it/s]
# Loading JSON files: 2it [00:00, 93.55it/s]
# Loading JSON files: 2it [00:00, 73.84it/s]
# Loading JSON files: 2it [00:00, 227.35it/s]
# Loading JSON files: 2it [00:00, 272.94it/s]
# Loading JSON files: 80it [00:00, 989.93it/s]
# Loading JSON files: 95it [00:00, 1040.09it/s]
# Loading JSON files: 146it [00:01, 90.27it/s]
# Loading JSON files: 80it [00:00, 1234.54it/s]
# Loading JSON files: 2it [00:00, 73.29it/s]
# Loading JSON files: 142it [00:01, 80.86it/s]
# Loading JSON files: 2it [00:00, 80.20it/s]
# Loading JSON files: 70it [00:00, 1930.38it/s]
# Loading JSON files: 90it [00:00, 1020.61it/s]
# Loading JSON files: 2it [00:00, 44.53it/s]
# Loading JSON files: 2it [00:00, 30.17it/s]
# Loading JSON files: 2it [00:00, 28.28it/s]
# Loading JSON files: 2it [00:00, 54.20it/s]
# Loading JSON files: 82it [00:00, 918.92it/s]
# Loading JSON files: 163it [00:01, 91.59it/s]
# Loading JSON files: 2it [00:00, 168.11it/s]
# Loading JSON files: 2it [00:00, 80.01it/s]
# Loading JSON files: 2it [00:00, 288.88it/s]
# Loading JSON files: 146it [00:01, 83.09it/s]
# Loading JSON files: 84it [00:00, 922.33it/s]
# Loading JSON files: 2it [00:00, 329.92it/s]
# Loading JSON files: 2it [00:00, 56.36it/s]
# Loading JSON files: 79it [00:00, 2244.42it/s]
# Loading JSON files: 2it [00:00, 50.46it/s]
# Loading JSON files: 2it [00:00, 85.77it/s]
# Loading JSON files: 2it [00:00, 184.50it/s]
# Loading JSON files: 2it [00:00, 57.28it/s]
# Loading JSON files: 73it [00:00, 2096.09it/s]
# Loading JSON files: 75it [00:00, 2231.39it/s]
# Loading JSON files: 2it [00:00, 283.31it/s]
# Loading JSON files: 2it [00:00, 44.93it/s]
# Loading JSON files: 2it [00:00, 54.33it/s]
# Loading JSON files: 145it [00:01, 87.28it/s]
# Loading JSON files: 2it [00:00, 48.05it/s]
# Loading JSON files: 77it [00:00, 88.63it/s]
# Loading JSON files: 2it [00:00, 65.39it/s]
# Loading JSON files: 2it [00:00, 47.84it/s]
# Loading JSON files: 74it [00:00, 1224.72it/s]
# Loading JSON files: 2it [00:00, 330.36it/s]
# Loading JSON files: 2it [00:00, 77.71it/s]
# Loading JSON files: 96it [00:00, 1018.94it/s]
# Loading JSON files: 2it [00:00, 60.58it/s]
# Loading JSON files: 2it [00:00, 46.56it/s]
# Loading JSON files: 88it [00:00, 1090.10it/s]
# Loading JSON files: 2it [00:00, 286.19it/s]
# Loading JSON files: 2it [00:00, 106.74it/s]
# Loading JSON files: 2it [00:00, 39.96it/s]
# Loading JSON files: 2it [00:00, 276.33it/s]
# Loading JSON files: 2it [00:00, 109.53it/s]
# Loading JSON files: 64it [00:00, 857.87it/s]
# Loading JSON files: 96it [00:00, 918.47it/s]
# Loading JSON files: 2it [00:00, 155.35it/s]
# Loading JSON files: 2it [00:00, 278.60it/s]
# Loading JSON files: 2it [00:00, 41.87it/s]
# Loading JSON files: 91it [00:00, 1410.64it/s]
# Loading JSON files: 194it [00:02, 91.81it/s]
# Loading JSON files: 2it [00:00, 184.18it/s]
# Loading JSON files: 98it [00:00, 1033.65it/s]
# Loading JSON files: 2it [00:00, 220.05it/s]
# Loading JSON files: 131it [00:01, 88.64it/s]
# Loading JSON files: 2it [00:00, 51.98it/s]
# Loading JSON files: 2it [00:00, 47.36it/s]
# Loading JSON files: 2it [00:00, 239.24it/s]
# Loading JSON files: 122it [00:01, 89.06it/s]
# Loading JSON files: 71it [00:00, 1778.47it/s]
# Loading JSON files: 127it [00:01, 114.57it/s]
# Loading JSON files: 2it [00:00, 46.76it/s]
# Loading JSON files: 52it [00:00, 1415.43it/s]
# Loading JSON files: 99it [00:00, 1093.87it/s]
# Loading JSON files: 2it [00:00, 190.84it/s]
# Loading JSON files: 2it [00:00, 63.56it/s]
# Loading JSON files: 89it [00:00, 2023.88it/s]
# Loading JSON files: 72it [00:00, 2099.56it/s]
# Loading JSON files: 123it [00:01, 89.39it/s]
# Loading JSON files: 73it [00:00, 1688.32it/s]
# Loading JSON files: 118it [00:01, 84.62it/s]
# Loading JSON files: 2it [00:00, 50.93it/s]
# Loading JSON files: 2it [00:00, 55.38it/s]
# Loading JSON files: 166it [00:01, 89.49it/s]
# Loading JSON files: 134it [00:01, 90.36it/s]
# Loading JSON files: 2it [00:00, 208.88it/s]
# Loading JSON files: 2it [00:00, 222.80it/s]
# Loading JSON files: 2it [00:00, 80.15it/s]
# Loading JSON files: 2it [00:00, 57.44it/s]
# Loading JSON files: 2it [00:00, 44.32it/s]
# Loading JSON files: 83it [00:00, 1036.55it/s]
# Loading JSON files: 101it [00:01, 85.45it/s]
# Loading JSON files: 2it [00:00, 180.75it/s]
# Loading JSON files: 70it [00:00, 2178.92it/s]
# Loading JSON files: 161it [00:01, 91.09it/s]
# Loading JSON files: 79it [00:00, 746.68it/s]
# Loading JSON files: 2it [00:00, 89.16it/s]
# Loading JSON files: 2it [00:00, 192.70it/s]
# Loading JSON files: 2it [00:00, 153.75it/s]
# Loading JSON files: 70it [00:00, 1359.03it/s]
# Loading JSON files: 113it [00:01, 89.97it/s]
# Loading JSON files: 2it [00:00, 50.24it/s]
# Loading JSON files: 2it [00:00, 47.28it/s]
# Loading JSON files: 2it [00:00, 317.37it/s]
# Loading JSON files: 2it [00:00, 518.58it/s]
# Loading JSON files: 2it [00:00, 44.32it/s]
# Loading JSON files: 2it [00:00, 194.52it/s]
# Loading JSON files: 88it [00:00, 986.30it/s]
# Loading JSON files: 165it [00:00, 1510.52it/s]
# Loading JSON files: 2it [00:00, 103.85it/s]
# Loading JSON files: 2it [00:00, 113.48it/s]
# Loading JSON files: 2it [00:00, 193.38it/s]
# Loading JSON files: 63it [00:00, 1310.60it/s]
# Loading JSON files: 98it [00:00, 968.76it/s]
# Loading JSON files: 2it [00:00, 42.71it/s]
# Loading JSON files: 2it [00:00, 117.94it/s]
# Loading JSON files: 169it [00:01, 91.72it/s]
# Loading JSON files: 2it [00:00, 243.32it/s]
# Loading JSON files: 107it [00:01, 88.33it/s]
# Loading JSON files: 2it [00:00, 77.89it/s]
# Loading JSON files: 73it [00:00, 1368.64it/s]
# Loading JSON files: 69it [00:00, 851.36it/s]
# Loading JSON files: 171it [00:01, 91.66it/s]
# Loading JSON files: 79it [00:00, 918.91it/s]
# Loading JSON files: 2it [00:00, 142.18it/s]
# Loading JSON files: 2it [00:00, 35.12it/s]
# Loading JSON files: 2it [00:00, 45.13it/s]
# Loading JSON files: 2it [00:00, 243.75it/s]
# Loading JSON files: 60it [00:00, 1039.18it/s]
# Loading JSON files: 2it [00:00, 208.97it/s]
# Loading JSON files: 106it [00:00, 1103.85it/s]
# Loading JSON files: 2it [00:00, 84.79it/s]
# Loading JSON files: 175it [00:02, 87.12it/s]
# Loading JSON files: 90it [00:00, 1087.70it/s]
# Loading JSON files: 2it [00:00, 244.77it/s]
# Loading JSON files: 70it [00:00, 1344.99it/s]
# Loading JSON files: 100it [00:01, 84.53it/s]
# Loading JSON files: 2it [00:00, 73.94it/s]
# Loading JSON files: 75it [00:00, 1390.75it/s]
# Loading JSON files: 121it [00:01, 84.46it/s]
# Loading JSON files: 71it [00:00, 1208.98it/s]
# Loading JSON files: 2it [00:00, 41.87it/s]
# Loading JSON files: 66it [00:00, 89.00it/s]
# Loading JSON files: 2it [00:00, 68.29it/s]
# Loading JSON files: 2it [00:00, 57.69it/s]
# Loading JSON files: 2it [00:00, 80.40it/s]
# Loading JSON files: 2it [00:00, 42.15it/s]
# Loading JSON files: 2it [00:00, 45.70it/s]
# Loading JSON files: 100it [00:00, 1030.57it/s]
# Loading JSON files: 2it [00:00, 89.42it/s]
# Loading JSON files: 2it [00:00, 65.80it/s]
# Loading JSON files: 105it [00:00, 1066.91it/s]
# Loading JSON files: 65it [00:00, 1397.10it/s]
# Loading JSON files: 82it [00:00, 1224.08it/s]
# Loading JSON files: 2it [00:00, 280.63it/s]
# Loading JSON files: 2it [00:00, 61.72it/s]
# Loading JSON files: 92it [00:00, 922.10it/s]
# Loading JSON files: 2it [00:00, 71.39it/s]
# Loading JSON files: 2it [00:00, 51.54it/s]
# Loading JSON files: 2it [00:00, 233.84it/s]
# Loading JSON files: 2it [00:00, 230.72it/s]
# Loading JSON files: 2it [00:00, 79.75it/s]
# Loading JSON files: 126it [00:01, 89.66it/s]
# Loading JSON files: 132it [00:01, 90.11it/s]
# Loading JSON files: 96it [00:00, 1125.24it/s]
# Loading JSON files: 138it [00:01, 91.76it/s]
# Loading JSON files: 2it [00:00, 233.74it/s]
# Loading JSON files: 68it [00:00, 1295.93it/s]
# Loading JSON files: 106it [00:01, 87.18it/s]
# Loading JSON files: 2it [00:00, 36.35it/s]
# Loading JSON files: 127it [00:01, 88.29it/s]
# Loading JSON files: 79it [00:00, 1072.37it/s]
# Loading JSON files: 70it [00:00, 912.45it/s]
# Loading JSON files: 96it [00:00, 974.27it/s]
# Loading JSON files: 81it [00:00, 1374.80it/s]
# Loading JSON files: 2it [00:00, 44.91it/s]
# Loading JSON files: 2it [00:00, 46.81it/s]
# Loading JSON files: 126it [00:01, 83.45it/s]
# Loading JSON files: 2it [00:00, 64.20it/s]
# Loading JSON files: 2it [00:00, 188.66it/s]
# Loading JSON files: 133it [00:01, 87.62it/s]
# Loading JSON files: 144it [00:01, 86.66it/s]
# Loading JSON files: 95it [00:01, 81.87it/s]
# Loading JSON files: 120it [00:01, 83.98it/s]
# Loading JSON files: 61it [00:00, 89.77it/s]
# Loading JSON files: 2it [00:00, 44.84it/s]
# Loading JSON files: 2it [00:00, 47.46it/s]
# Loading JSON files: 76it [00:00, 88.77it/s]
# Loading JSON files: 2it [00:00, 75.63it/s]
# Loading JSON files: 2it [00:00, 259.77it/s]
# Loading JSON files: 2it [00:00, 51.48it/s]
# Loading JSON files: 120it [00:01, 108.17it/s]
# Loading JSON files: 185it [00:02, 87.24it/s]
# Loading JSON files: 60it [00:00, 84.21it/s]
# Loading JSON files: 90it [00:01, 84.62it/s]
# Loading JSON files: 2it [00:00, 43.25it/s]
# Loading JSON files: 2it [00:00, 49.84it/s]
# Loading JSON files: 84it [00:00, 897.91it/s]
# Loading JSON files: 2it [00:00, 48.54it/s]
# Loading JSON files: 2it [00:00, 65.38it/s]
# Loading JSON files: 70it [00:00, 1319.55it/s]
# Loading JSON files: 2it [00:00, 263.57it/s]
# Loading JSON files: 2it [00:00, 47.28it/s]
# Loading JSON files: 104it [00:00, 1397.26it/s]
# Loading JSON files: 2it [00:00, 70.96it/s]
# Loading JSON files: 2it [00:00, 47.59it/s]
# Loading JSON files: 2it [00:00, 177.15it/s]
# Loading JSON files: 160it [00:01, 88.27it/s]
# Loading JSON files: 55it [00:00, 1152.89it/s]
# Loading JSON files: 89it [00:00, 837.12it/s]
# Loading JSON files: 2it [00:00, 570.07it/s]
# Loading JSON files: 2it [00:00, 75.82it/s]
# Loading JSON files: 2it [00:00, 96.25it/s]
# Loading JSON files: 159it [00:01, 88.91it/s]
# Loading JSON files: 2it [00:00, 51.27it/s]
# Loading JSON files: 70it [00:00, 1435.89it/s]
# Loading JSON files: 194it [00:02, 89.29it/s]
# Loading JSON files: 114it [00:01, 89.20it/s]
# Loading JSON files: 64it [00:00, 1430.25it/s]
# Loading JSON files: 2it [00:00, 76.43it/s]
# Loading JSON files: 2it [00:00, 49.49it/s]
# Loading JSON files: 104it [00:00, 1028.97it/s]
# Loading JSON files: 76it [00:00, 931.82it/s]
# Loading JSON files: 93it [00:00, 1001.38it/s]
# Loading JSON files: 85it [00:00, 989.65it/s]
# Loading JSON files: 73it [00:00, 1451.14it/s]
# Loading JSON files: 158it [00:01, 83.63it/s]
# Loading JSON files: 74it [00:00, 1034.67it/s]
# Loading JSON files: 74it [00:00, 93.45it/s]
# Loading JSON files: 81it [00:00, 937.96it/s]
# Loading JSON files: 82it [00:00, 970.71it/s]
# Loading JSON files: 2it [00:00, 56.97it/s]
# Loading JSON files: 63it [00:00, 769.29it/s]
# Loading JSON files: 2it [00:00, 231.42it/s]
# Loading JSON files: 150it [00:00, 1578.86it/s]
# Loading JSON files: 121it [00:01, 87.15it/s]
# Loading JSON files: 152it [00:01, 88.82it/s]
# Loading JSON files: 2it [00:00, 44.01it/s]
# Loading JSON files: 175it [00:02, 81.96it/s]
# Loading JSON files: 110it [00:01, 80.73it/s]
# Loading JSON files: 73it [00:00, 984.68it/s]
# Loading JSON files: 2it [00:00, 205.57it/s]
# Loading JSON files: 171it [00:02, 72.42it/s]
# Loading JSON files: 57it [00:00, 1021.91it/s]
# Loading JSON files: 2it [00:00, 51.81it/s]
# Loading JSON files: 64it [00:00, 1278.11it/s]
# Loading JSON files: 2it [00:00, 192.29it/s]
# Loading JSON files: 166it [00:02, 74.62it/s]
# Loading JSON files: 2it [00:00, 190.08it/s]
# Loading JSON files: 188it [00:02, 81.54it/s]
# Loading JSON files: 58it [00:00, 617.27it/s]
# Loading JSON files: 2it [00:00, 51.89it/s]
# Loading JSON files: 83it [00:00, 868.50it/s]
# Loading JSON files: 96it [00:00, 1245.81it/s]
# Loading JSON files: 62it [00:00, 1206.92it/s]
# Loading JSON files: 2it [00:00, 47.08it/s]
# Loading JSON files: 2it [00:00, 49.99it/s]
# Loading JSON files: 59it [00:00, 1206.99it/s]
# Loading JSON files: 79it [00:01, 70.54it/s]
# Loading JSON files: 138it [00:01, 80.01it/s]
# Loading JSON files: 2it [00:00, 42.18it/s]
# Loading JSON files: 2it [00:00, 42.16it/s]
# Loading JSON files: 2it [00:00, 46.90it/s]
# Loading JSON files: 2it [00:00, 198.96it/s]
# Loading JSON files: 70it [00:00, 1386.51it/s]
# Loading JSON files: 150it [00:01, 78.68it/s]
# Loading JSON files: 69it [00:00, 767.36it/s]
# Loading JSON files: 81it [00:00, 888.46it/s]
# Loading JSON files: 125it [00:01, 76.71it/s]
# Loading JSON files: 65it [00:00, 1123.93it/s]
# Loading JSON files: 2it [00:00, 47.31it/s]
# Loading JSON files: 2it [00:00, 78.97it/s]
# Loading JSON files: 2it [00:00, 61.75it/s]
# Loading JSON files: 84it [00:00, 84.85it/s]
# Loading JSON files: 2it [00:00, 39.58it/s]
# Loading JSON files: 2it [00:00, 202.34it/s]
# Loading JSON files: 64it [00:00, 1238.73it/s]
# Loading JSON files: 2it [00:00, 34.32it/s]
# 57442
# Processing JSON files: 100%|██████████| 57442/57442 [00:03<00:00, 15481.86it/s]
# Processed 1742107 text chunks.
# Saved content_dict with text chunks.
# Generating embeddings:   0%|          | 4123/871054 [27:13<31844:47:44, 132.24s/it]
# Error generating embedding for batch 8244: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Generating embeddings:   1%|▏         | 11068/871054 [1:09:23<25092:06:49, 105.04s/it]
# Error generating embedding for batch 22134: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Generating embeddings:   1%|▏         | 11166/871054 [1:09:54<89:43:18,  2.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 191
#     189 # Generate embeddings from text chunks
#     190 try:
# --> 191     embeddings = generate_embeddings_from_chunks(content_dict, batch_size=2)
#     192     print(f"Generated embeddings for {len(embeddings)} chunks.")
#     193 except Exception as e:
#
# Cell In[8], line 99, in generate_embeddings_from_chunks(chunks, batch_size)
#      96 try:
#      97     # Extract text content for embedding generation
#      98     batch_texts = [item["text_chunk"] for item in batch]
# ---> 99     response = openai.Embedding.create(
#     100         model="text-embedding-ada-002",
#     101         input=batch_texts
#     102     )
#     103     # Add embeddings with corresponding IDs
#     104     for j, embedding in enumerate(response["data"]):
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\openai\api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\openai\api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\chiranjit usa\OneDrive - Northeastern University\Desktop\vector_database_project\venv\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
content_dict
# Out:
# [{'id': '0865-02.json_chunk_0',
#   'text_chunk': '{"id": 3941806, "name": "Madeline C. Whiting vs. Robertson Construction Company, Inc.", "name_abbreviation": "Whiting v. Robertson Construction Co.", "decision_date": "1974-01-07", "docket_number": "", "first_page": "865", "last_page": "865", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 865"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "342 Mass. 483", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3856245], "year": 1961, "pin_cites": [{"page": "487"}], "opinion_index": 0, "case_paths": ["/mass/342/0483-01"]}, {"cite": "146 Mass. 465", "category": "reporters:state", "reporter": "Mass.", "case_ids": [784110], "year": 1888, "pin_cites": [{"page": "466"}], "opinion_index": 0, "case_paths": ["/mass/146/0465-01"]}, {"cite": "135 Mass. 122", "category": "reporters:state", "reporter": "Mass.", "case_ids": ['},
#  {'id': '0865-02.json_chunk_1',
#   'text_chunk': '10], "year": 1888, "pin_cites": [{"page": "466"}], "opinion_index": 0, "case_paths": ["/mass/146/0465-01"]}, {"cite": "135 Mass. 122", "category": "reporters:state", "reporter": "Mass.", "case_ids": [724546], "year": 1883, "pin_cites": [{"page": "124-125"}], "opinion_index": 0, "case_paths": ["/mass/135/0122-01"]}], "analysis": {"cardinality": 184, "char_count": 1994, "ocr_confidence": 0.908, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12139974183823073}, "sha256": "9fe4ff359109c4257dcf5994694061a75c523ce1f3277856b01814e6745ce5e9", "simhash": "1:6e2e836748b917aa", "word_count": 328}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Madeline C. Whiting vs. Robertson Construction Company, Inc."], "opinions": [{"text": "This petition for a writ of review was allowed in the Superior Court. The respondent\\u2019s bill of exceptions raises the question whe'},
#  {'id': '0865-02.json_chunk_2',
#   'text_chunk': 's. Robertson Construction Company, Inc."], "opinions": [{"text": "This petition for a writ of review was allowed in the Superior Court. The respondent\\u2019s bill of exceptions raises the question whether its requests for rulings,- in effect that the petition for a writ of review should be dismissed because filed beyond the statutory period (see G.L. c. 250, \\u00a7 22), should have been granted. The petition filed February 13, 1973, seeks review of \\u00e1 judgment in an action of contract which was rendered against the petitioner (defendant therein) on November 1,1971, for failure to answer interrogatories and of which the petitioner \\u201cpersonally never did receive notice\\u201d until December, 1972. Since the petition was filed more than a year after judgment, it could be maintained only if the judgment \\u201cwas rendered in the absence of the petitioner and without... [her] knowledge ....\\u201d The petitioner was not \\u201cabsent\\u201d within the meaning of \\u00a7 22 when judgment '},
#  {'id': '0865-02.json_chunk_3',
#   'text_chunk': 'y if the judgment \\u201cwas rendered in the absence of the petitioner and without... [her] knowledge ....\\u201d The petitioner was not \\u201cabsent\\u201d within the meaning of \\u00a7 22 when judgment was rendered since she had been served with process and since an appearance had been entered on her behalf. Matthewson v. Moulton, 135 Mass. 122, 124-125 (1883). Riley v. Hale, 146 Mass. 465, 466 (1888). \\u201cAbsence of the defendant... means simply the antithesis of presence secured by... [her] entering an appearance or by the service of process upon ... [her].\\u201d Reubens v. Boston Fed. Sau. & Loan Assn. 342 Mass. 483, 487 (1961). The short answer to the petitioner\\u2019s contention that the trial judge had discretion to grant the petition is also found in the Reubens case (which held that it was error to deny requests for rulings of law virtually identical with those denied in this case) in which the Supreme Judicial Court said (p. 487), \\u201cOf course, he [the trial judge] has no d'},
#  {'id': '0865-02.json_chunk_4',
#   'text_chunk': 't it was error to deny requests for rulings of law virtually identical with those denied in this case) in which the Supreme Judicial Court said (p. 487), \\u201cOf course, he [the trial judge] has no discretion to act counter to the provisions of the statute.\\u201d The respondent\\u2019s requests for rulings of law should have been granted.\\nExceptions sustained.\\nPetition dismissed.", "type": "majority", "author": null}], "attorneys": ["Frederick T. Colder for the respondent.", "Ro b ert L. A thas for the petitioner."], "corrections": "", "head_matter": "Madeline C. Whiting vs. Robertson Construction Company, Inc.\\nJanuary 7, 1974.\\nFrederick T. Colder for the respondent.\\nRo b ert L. A thas for the petitioner."}, "file_name": "0865-02", "first_page_order": 881, "last_page_order": 881}'},
#  {'id': '0865-03.json_chunk_0',
#   'text_chunk': '{"id": 3943220, "name": "Joseph E. Fletcher vs. James F. Dockery", "name_abbreviation": "Fletcher v. Dockery", "decision_date": "1974-01-07", "docket_number": "", "first_page": "865", "last_page": "866", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 865"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "356 Mass. 712", "category": "reporters:state", "reporter": "Mass.", "case_ids": [300504], "pin_cites": [{"page": "713-714"}], "opinion_index": 0, "case_paths": ["/mass/356/0712-01"]}, {"cite": "356 Mass. 465", "category": "reporters:state", "reporter": "Mass.", "case_ids": [300516], "opinion_index": 0, "case_paths": ["/mass/356/0465-01"]}, {"cite": "302 Mass. 411", "category": "reporters:state", "reporter": "Mass.", "case_ids": [867829], "pin_cites": [{"page": "413-414"}], "opinion_index": 0, "case_paths": ["/mass/302/0411-'},
#  {'id': '0865-03.json_chunk_1',
#   'text_chunk': '/0465-01"]}, {"cite": "302 Mass. 411", "category": "reporters:state", "reporter": "Mass.", "case_ids": [867829], "pin_cites": [{"page": "413-414"}], "opinion_index": 0, "case_paths": ["/mass/302/0411-01"]}, {"cite": "362 Mass. 803", "category": "reporters:state", "reporter": "Mass.", "case_ids": [43975], "weight": 2, "year": 1973, "pin_cites": [{"page": "805-806"}, {"page": "806"}], "opinion_index": 0, "case_paths": ["/mass/362/0803-01"]}, {"cite": "336 Mass. 436", "category": "reporters:state", "reporter": "Mass.", "case_ids": [881840], "year": 1957, "opinion_index": 0, "case_paths": ["/mass/336/0436-01"]}, {"cite": "332 Mass. 213", "category": "reporters:state", "reporter": "Mass.", "case_ids": [938193], "year": 1955, "pin_cites": [{"page": "214-215"}], "opinion_index": 0, "case_paths": ["/mass/332/0213-01"]}, {"cite": "318 Mass. 711", "category": "reporters:state", "reporter": "Mass.", "case_ids": [929869], "year": 1945, "pin_cites": [{"page": "712-713"}], "opinion_index": 0, "case_'},
#  {'id': '0865-03.json_chunk_2',
#   'text_chunk': '["/mass/332/0213-01"]}, {"cite": "318 Mass. 711", "category": "reporters:state", "reporter": "Mass.", "case_ids": [929869], "year": 1945, "pin_cites": [{"page": "712-713"}], "opinion_index": 0, "case_paths": ["/mass/318/0711-01"]}, {"cite": "289 Mass. 595", "category": "reporters:state", "reporter": "Mass.", "case_ids": [492838], "year": 1935, "pin_cites": [{"page": "596-598"}], "opinion_index": 0, "case_paths": ["/mass/289/0595-01"]}, {"cite": "278 Mass. 339", "category": "reporters:state", "reporter": "Mass.", "case_ids": [859544], "year": 1932, "pin_cites": [{"page": "340-341"}], "opinion_index": 0, "case_paths": ["/mass/278/0339-01"]}, {"cite": "273 Mass. 275", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3826787], "year": 1930, "pin_cites": [{"page": "276-277"}], "opinion_index": 0, "case_paths": ["/mass/273/0275-01"]}], "analysis": {"cardinality": 252, "char_count": 2721, "ocr_confidence": 0.905, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.121444'},
#  {'id': '0865-03.json_chunk_3',
#   'text_chunk': 'opinion_index": 0, "case_paths": ["/mass/273/0275-01"]}], "analysis": {"cardinality": 252, "char_count": 2721, "ocr_confidence": 0.905, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12144453209434218}, "sha256": "b2b07f039a7fa6197218580e6c1b4086c3a7c9067f974d9022751e9ef0dd9830", "simhash": "1:2808efd5ddf42ce9", "word_count": 472}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Joseph E. Fletcher vs. James F. Dockery."], "opinions": [{"text": "This action of tort to recover for personal injuries and property damage resulting from the collision of an oil truck operated by the remaining defendant (defendant) with a truck owned and operated by the plaintiff is here on the defendant\\u2019s exception to the denial of his motion for directed verdicts presented at the conclusion of the plaintiff s case. The evidence most favorable to the plaintiff (which do'},
#  {'id': '0865-03.json_chunk_4',
#   'text_chunk': ' is here on the defendant\\u2019s exception to the denial of his motion for directed verdicts presented at the conclusion of the plaintiff s case. The evidence most favorable to the plaintiff (which does not include a possible explanation by the defendant of how the accident might have happened) is summarized: Between 3:00 and 3:45 p.m. on the clear, dry day of January 23, 1968, the plaintiff, who had been driving along a divided highway in Medford, stopped his truck for a red light, coming to a halt in the extreme right hand of three lanes. At that time there was no vehicle stopped in either of the lanes lying to the plaintiff s left. The plaintiff had been stopped for about twenty seconds when his truck was struck in the rear by the truck operated by the defendant. The force of the impact was such that (apparently after rebound) the plaintiff s chest hit the steering wheel of his truck, his body hit the steering post, and his knees hit the dashboard; \\u201c [hjis knees were all messed'},
#  {'id': '0865-03.json_chunk_5',
#   'text_chunk': ' was such that (apparently after rebound) the plaintiff s chest hit the steering wheel of his truck, his body hit the steering post, and his knees hit the dashboard; \\u201c [hjis knees were all messed up and his groin part was all black and blue from his stomach all the way down to his knees.\\u201d A spring was broken in the starter mechanism of his truck. On that evidence there were questions of fact for the jury as to the defendant\\u2019s speed and as to whether he should have seen the plaintiff s truck in sufficient time to avoid the accident by stopping or by turning to the left. Murphy v. New England Transp. Co. 273 Mass. 275, 276-277 (1930). Hendler v. Coffey, 278 Mass. 339, 340-341 (1932). Jennings v. Bragdon, 289 Mass. 595, 596-598 (1935). Lech v. Escobar, 318 Mass. 711, 712-713 (1945). Warren v. Howe, 332 Mass. 213, 214-215 (1955). Harrington v. Central Greyhound Lines, Inc. of N. Y. 336 Mass. 436 (1957). Olofson v. Kilgallon, 362 Mass. 803, 805-806 (1973). This was not a case'},
#  {'id': '0865-03.json_chunk_6',
#   'text_chunk': '945). Warren v. Howe, 332 Mass. 213, 214-215 (1955). Harrington v. Central Greyhound Lines, Inc. of N. Y. 336 Mass. 436 (1957). Olofson v. Kilgallon, 362 Mass. 803, 805-806 (1973). This was not a case (such as Buda v. Foley, 302 Mass. 411, 413-414 [1939], or Frazier v. Cordialino, 356 Mass. 465 [1969]) in which the defendant could not foresee the intervening act of a third person or one (such as Varisco v. Malovin, 356 Mass. 712, 713-714 [1970]) in which the plaintiffs vehicle was \\u201cstopped on an open highway\\u201d (Olofson v. Kilgallon, 362 Mass. 803, 806 [1973]).\\nThomas D. Burns (Mitchell J. Sikora, Jr., with him) for the defendant.\\nThomas F. Sullivan for the plaintiff.\\nExceptions overruled.\\nThe other original defendant (Elizabeth Decandia) and a third-party defendant (Albert Robbins) were eliminated from the case by directed verdicts which are not questioned.", "type": "majority", "author": null}], "attorneys": ["Thomas D. Burns (Mitchell J. Sikora, Jr., with him) for the de'},
#  {'id': '0865-03.json_chunk_7',
#   'text_chunk': 'bins) were eliminated from the case by directed verdicts which are not questioned.", "type": "majority", "author": null}], "attorneys": ["Thomas D. Burns (Mitchell J. Sikora, Jr., with him) for the defendant.", "Thomas F. Sullivan for the plaintiff."], "corrections": "", "head_matter": "Joseph E. Fletcher vs. James F. Dockery.\\nJanuary 7, 1974."}, "file_name": "0865-03", "first_page_order": 881, "last_page_order": 882}'},
#  {'id': '0866-01.json_chunk_0',
#   'text_chunk': '{"id": 3942935, "name": "Commonwealth vs. Stephen Wainio", "name_abbreviation": "Commonwealth v. Wainio", "decision_date": "1974-01-08", "docket_number": "", "first_page": "866", "last_page": "867", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 866"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "358 Mass. 242", "category": "reporters:state", "reporter": "Mass.", "case_ids": [298501], "year": 1970, "pin_cites": [{"page": "244"}], "opinion_index": 0, "case_paths": ["/mass/358/0242-01"]}, {"cite": "343 Mass. 19", "category": "reporters:state", "reporter": "Mass.", "case_ids": [4022731], "year": 1961, "pin_cites": [{"page": "21-22"}], "opinion_index": 0, "case_paths": ["/mass/343/0019-01"]}, {"cite": "333 Mass. 78", "category": "reporters:state", "reporter": "Mass.", "case_ids": [488551], "year": 1955, "pin_cites": [{"page"'},
#  {'id': '0866-01.json_chunk_1',
#   'text_chunk': '-22"}], "opinion_index": 0, "case_paths": ["/mass/343/0019-01"]}, {"cite": "333 Mass. 78", "category": "reporters:state", "reporter": "Mass.", "case_ids": [488551], "year": 1955, "pin_cites": [{"page": "79, 82"}], "opinion_index": 0, "case_paths": ["/mass/333/0078-01"]}, {"cite": "207 Mass. 259", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3476957], "year": 1911, "pin_cites": [{"page": "265-268"}], "opinion_index": 0, "case_paths": ["/mass/207/0259-01"]}, {"cite": "10 Cush. 52", "category": "reporters:state", "reporter": "Cush.", "case_ids": [1991506], "pin_cites": [{"page": "54-55"}], "opinion_index": 0, "case_paths": ["/mass/64/0052-01"]}, {"cite": "376 U. S. 933", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [379425, 379470, 379187, 379775, 379032, 379422, 379039], "opinion_index": 0, "case_paths": ["/us/376/0933-03", "/us/376/0933-06", "/us/376/0933-04", "/us/376/0933-01", "/us/376/0933-07", "/us/376/0933-05", "/us/376/0933-02"]}, {"cite": "'},
#  {'id': '0866-01.json_chunk_2',
#   'text_chunk': '2, 379422, 379039], "opinion_index": 0, "case_paths": ["/us/376/0933-03", "/us/376/0933-06", "/us/376/0933-04", "/us/376/0933-01", "/us/376/0933-07", "/us/376/0933-05", "/us/376/0933-02"]}, {"cite": "346 Mass. 373", "category": "reporters:state", "reporter": "Mass.", "case_ids": [518377], "pin_cites": [{"page": "377-378"}], "opinion_index": 0, "case_paths": ["/mass/346/0373-01"]}, {"cite": "189 Mass. 12", "category": "reporters:state", "reporter": "Mass.", "case_ids": [461700], "pin_cites": [{"page": "18-19"}], "opinion_index": 0, "case_paths": ["/mass/189/0012-01"]}, {"cite": "337 Mass. 264", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3847808], "pin_cites": [{"page": "266"}], "opinion_index": 0, "case_paths": ["/mass/337/0264-01"]}], "analysis": {"cardinality": 223, "char_count": 2232, "ocr_confidence": 0.919, "pagerank": {"raw": 1.0411641524360182e-07, "percentile": 0.5507996798268934}, "sha256": "36a20f5a71789c8de5454ae37223062da6428083b979a77c90837d98ad9a5eb7"'},
#  {'id': '0866-01.json_chunk_3',
#   'text_chunk': '"char_count": 2232, "ocr_confidence": 0.919, "pagerank": {"raw": 1.0411641524360182e-07, "percentile": 0.5507996798268934}, "sha256": "36a20f5a71789c8de5454ae37223062da6428083b979a77c90837d98ad9a5eb7", "simhash": "1:8960cc5d511f4926", "word_count": 385}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Commonwealth vs. Stephen Wainio."], "opinions": [{"text": "The defendant excepted to the denial of his motion (filed in the Superior Court) to dismiss (\\u201con the ground that it fails to state a crime\\u201d) a complaint which alleged in material part that on a given date \\u201cat Boxborough ... [the defendant] did in the Daytime, break and enter the dwelling house of [named individual], with intent to commit a felony, no person lawfully therein being put in, fear, contrary to the provisions of [G. L. c. 266, \\u00a7 18] ....\\u201d The defendant was found guilty an'},
#  {'id': '0866-01.json_chunk_4',
#   'text_chunk': ' [named individual], with intent to commit a felony, no person lawfully therein being put in, fear, contrary to the provisions of [G. L. c. 266, \\u00a7 18] ....\\u201d The defendant was found guilty and sentenced following a jury waived trial and has appealed under G. L. c. 278, \\u00a7 28. We assume in his favor (although it is by no means clear from the record) that the arguments now presented to us were also presented to the Superior Court. A perusal of the record (which does not disclose any of the proceedings at trial; see Guerin v. Commonwealth, 337 Mass. 264, 266 [1958]) and briefs leads us to the conclusion that if the defendant wished to question the sufficiency of the complaint because it was not framed in the language of one of the forms found in G. L. c. 277, \\u00a7 79 (as to which see Commonwealth v. Snell, 189 Mass. 12,18-19 [1905]), or wished to be apprised of a particular felony intended to be committed (as to which see Commonwealth v. Lewis, 346 Mass. 373, 377-378 [1963]'},
#  {'id': '0866-01.json_chunk_5',
#   'text_chunk': 'ch see Commonwealth v. Snell, 189 Mass. 12,18-19 [1905]), or wished to be apprised of a particular felony intended to be committed (as to which see Commonwealth v. Lewis, 346 Mass. 373, 377-378 [1963], cert. den. sub nom. Lewis v. Massachusetts, 376 U. S. 933 [1964]), or believed (despite the decision in Commonwealth v. Doherty, 10 Cush. 52, 54-55 [1852]) that the complaint was deficient for failure to allege intent to commit a felony inside the building broken into (as to which see Perkins, Criminal Law [2d ed.] 212), he should have availed himself of the remedy (not here employed) of a motion for a bill of particulars. G. L. c. 277, \\u00a7\\u00a7 34 and 40. See Commonwealth v. Jordan, 207 Mass. 259, 265-268 (1911); Commonwealth v. Ronchetti, 333 Mass. 78, 79, 82 (1955); Persampieri v. Commonwealth, 343 Mass. 19, 21-22 (1961); Commonwealth v. Valleca, 358 Mass. 242, 244 (1970).\\nThe case was submitted on briefs.\\nWilliam A. Nelson for the defendant.\\nJohn J. Droney, District Attorney, '},
#  {'id': '0866-01.json_chunk_6',
#   'text_chunk': 'monwealth, 343 Mass. 19, 21-22 (1961); Commonwealth v. Valleca, 358 Mass. 242, 244 (1970).\\nThe case was submitted on briefs.\\nWilliam A. Nelson for the defendant.\\nJohn J. Droney, District Attorney, Terence M. Troyer & Bonnie H. MacLeod-Griffin, Assistant District Attorneys, for the Commonwealth.\\nJudgment affirmed.", "type": "majority", "author": null}], "attorneys": ["The case was submitted on briefs.", "William A. Nelson for the defendant.", "John J. Droney, District Attorney, Terence M. Troyer & Bonnie H. MacLeod-Griffin, Assistant District Attorneys, for the Commonwealth."], "corrections": "", "head_matter": "Commonwealth vs. Stephen Wainio.\\nJanuary 8, 1974."}, "file_name": "0866-01", "first_page_order": 882, "last_page_order": 883}'},
#  {'id': '0867-01.json_chunk_0',
#   'text_chunk': '{"id": 3943494, "name": "Charles Mancuso vs. Francesca Mancuso", "name_abbreviation": "Mancuso v. Mancuso", "decision_date": "1974-01-18", "docket_number": "", "first_page": "867", "last_page": "868", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 867"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "325 Mass. 278", "category": "reporters:state", "reporter": "Mass.", "case_ids": [506300], "year": 1950, "pin_cites": [{"page": "279"}], "opinion_index": 0, "case_paths": ["/mass/325/0278-01"]}, {"cite": "362 Mass. 186", "category": "reporters:state", "reporter": "Mass.", "case_ids": [43947], "year": 1972, "pin_cites": [{"page": "188-189"}], "opinion_index": 0, "case_paths": ["/mass/362/0186-01"]}, {"cite": "350 Mass. 333", "category": "reporters:state", "reporter": "Mass.", "case_ids": [526952], "year": 1966, "pin_cites": [{"p'},
#  {'id': '0867-01.json_chunk_1',
#   'text_chunk': '88-189"}], "opinion_index": 0, "case_paths": ["/mass/362/0186-01"]}, {"cite": "350 Mass. 333", "category": "reporters:state", "reporter": "Mass.", "case_ids": [526952], "year": 1966, "pin_cites": [{"page": "334"}], "opinion_index": 0, "case_paths": ["/mass/350/0333-01"]}, {"cite": "342 Mass. 171", "category": "reporters:state", "reporter": "Mass.", "case_ids": [5878269], "weight": 2, "year": 1961, "pin_cites": [{"page": "172"}, {"page": "172"}], "opinion_index": 0, "case_paths": ["/mass/342/0171-01"]}], "analysis": {"cardinality": 167, "char_count": 1931, "ocr_confidence": 0.908, "pagerank": {"raw": 7.582533720593189e-08, "percentile": 0.44944705270461716}, "sha256": "bb70e86ce19cae4c1c8a082ff9c519b58838963d4688832f247d22142ed4dccc", "simhash": "1:2fc9bcd03d11f2fb", "word_count": 317}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Charles Mancuso vs. Francesca'},
#  {'id': '0867-01.json_chunk_2',
#   'text_chunk': 'st_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Charles Mancuso vs. Francesca Mancuso."], "opinions": [{"text": "This is an appeal from a decree of a Probate Court granting a divorce to the libellant and dismissing the libellee\\u2019s separate support petition. The evidence is reported, and there is a report of material facts. The judge found, among other things, that \\u201c[i]n 1964 the libellee\\u2019s mother and father came to live with the parties,\\u201d that \\u201c[t]he libellee\\u2019s brother would visit the parties nightly and the libellee\\u2019s brother\\u2019s wife would visit at least weekly,\\u201d that in 1966 \\u201cthe libellee\\u2019s family \\u2018had a reunion around the table,\\u2019 and the libellant was \\u2018left on the outside,\\u2019 \\u201d that \\u201c[t]he libellant was systematically excluded from the gatherings by the libellee and her family,\\u201'},
#  {'id': '0867-01.json_chunk_3',
#   'text_chunk': 'on around the table,\\u2019 and the libellant was \\u2018left on the outside,\\u2019 \\u201d that \\u201c[t]he libellant was systematically excluded from the gatherings by the libellee and her family,\\u201d that frequent arguments arose between the parties, that \\u201cin 1967 the libellee \\u2018cut off entirely\\u2019 all sexual relations,\\u201d that such refusal \\u201cwas because of her lack of affection for the libellant,\\u201d that \\u201cthe libellant left the marital home in June 1967,\\u201d and that \\u201cthe libellant attempted ... to return to the libellee but she refused to \\u2018take [him] back.\\u2019 \\u201d The judge concluded that \\u201cthe libellee\\u2019s conduct was sufficient to cause the libellant to leave the home and was premeditated and deliberate,\\u201d and granted the libellant a decree of divorce on the ground of desertion. Moutinho v. Moutinho, 342 Mass. 171, 172 (1961). The evidence supports the findings. The judge \\u201capparently believed one spouse rather than the o'},
#  {'id': '0867-01.json_chunk_4',
#   'text_chunk': 'nt a decree of divorce on the ground of desertion. Moutinho v. Moutinho, 342 Mass. 171, 172 (1961). The evidence supports the findings. The judge \\u201capparently believed one spouse rather than the other. We cannot say that he was plainly wrong.\\u201d Wilde v. Wilde, 350 Mass. 333, 334 (1966). Krasner v. Krasner, 362 Mass. 186, 188-189 (1972). The judge was not \\u201crequired to believe the testimony of either of the parties.\\u201d Hamilton v. Hamilton, 325 Mass. 278, 279 (1950). The decree is not inconsistent with the findings. Moutinho v. Moutinho, supra, at 172.\\nWilliam E. Hickey for the libellee.\\nPeter M. Palica (A. Russell Lucid, Jr., with him) for the libellant.\\nDecree affirmed.", "type": "majority", "author": null}], "attorneys": ["William E. Hickey for the libellee.", "Peter M. Palica (A. Russell Lucid, Jr., with him) for the libellant."], "corrections": "", "head_matter": "Charles Mancuso vs. Francesca Mancuso.\\nJanuary 18, 1974."}, "file_name": "0867-01", "first_page_orde'},
#  {'id': '0867-01.json_chunk_5',
#   'text_chunk': ' Palica (A. Russell Lucid, Jr., with him) for the libellant."], "corrections": "", "head_matter": "Charles Mancuso vs. Francesca Mancuso.\\nJanuary 18, 1974."}, "file_name": "0867-01", "first_page_order": 883, "last_page_order": 884}'},
#  {'id': '0868-01.json_chunk_0',
#   'text_chunk': '{"id": 3944695, "name": "John R. Prespolis, guardian, vs. Rose Hawkes & another", "name_abbreviation": "Prespolis v. Hawkes", "decision_date": "1974-01-22", "docket_number": "", "first_page": "868", "last_page": "868", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 868"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "313 Mass. 33", "category": "reporters:state", "reporter": "Mass.", "case_ids": [484586], "year": 1943, "opinion_index": 0, "case_paths": ["/mass/313/0033-01"]}, {"cite": "146 Mass. 395", "category": "reporters:state", "reporter": "Mass.", "case_ids": [784165], "year": 1888, "opinion_index": 0, "case_paths": ["/mass/146/0395-01"]}, {"cite": "130 Mass. 221", "category": "reporters:state", "reporter": "Mass.", "case_ids": [2127977], "year": 1881, "opinion_index": 0, "case_paths": ["/mass/130/0221-01"]}, {"cite":'},
#  {'id': '0868-01.json_chunk_1',
#   'text_chunk': 'ss/146/0395-01"]}, {"cite": "130 Mass. 221", "category": "reporters:state", "reporter": "Mass.", "case_ids": [2127977], "year": 1881, "opinion_index": 0, "case_paths": ["/mass/130/0221-01"]}, {"cite": "294 Mass. 86", "category": "reporters:state", "reporter": "Mass.", "case_ids": [481459], "year": 1936, "pin_cites": [{"page": "90-91"}], "opinion_index": 0, "case_paths": ["/mass/294/0086-01"]}, {"cite": "362 Mass. 770", "category": "reporters:state", "reporter": "Mass.", "case_ids": [44171], "year": 1973, "pin_cites": [{"page": "777-779"}], "opinion_index": 0, "case_paths": ["/mass/362/0770-01"]}, {"cite": "212 Mass. 224", "category": "reporters:state", "reporter": "Mass.", "case_ids": [5672760], "year": 1912, "pin_cites": [{"page": "226-228"}], "opinion_index": 0, "case_paths": ["/mass/212/0224-01"]}], "analysis": {"cardinality": 175, "char_count": 1992, "ocr_confidence": 0.919, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12150457420490539}, "sha256": "37403ff05cef185cf6f'},
#  {'id': '0868-01.json_chunk_2',
#   'text_chunk': '/0224-01"]}], "analysis": {"cardinality": 175, "char_count": 1992, "ocr_confidence": 0.919, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12150457420490539}, "sha256": "37403ff05cef185cf6f087b0a8ba0175c3e3b80285f835f29138c21d2ce7d12c", "simhash": "1:2c42a9ca5abe7037", "word_count": 334}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["John R. Prespolis, guardian, vs. Rose Hawkes & another."], "opinions": [{"text": "This petition in equity, brought in a Probate Court by the guardian of John V. Prespolis, seeks to have paid to the petitioner as such guardian the proceeds of insurance on the life of Roxine H. Prespolis, who was the mother of the ward, the sister of Rose Hawkes, and the estranged and late wife of the petitioner. The petitioner was appointed guardian after Roxine\\u2019s death. The judge found that Roxine had designated as the beneficiary '},
#  {'id': '0868-01.json_chunk_3',
#   'text_chunk': 'ister of Rose Hawkes, and the estranged and late wife of the petitioner. The petitioner was appointed guardian after Roxine\\u2019s death. The judge found that Roxine had designated as the beneficiary \\u201cRose Hawkes \\u2018guardian\\u2019 of... [John V. Prespolis]\\u201d and that it was Roxine\\u2019s intention \\u201cthat her sister was to be the \\u2018custodian\\u2019 or trustee of [the proceeds of the life insurance].\\u201d The court\\u2019s decree ordered the proceeds paid to Rose Hawkes \\u201cas trustee for the benefit of said John V. Prespolis until he reaches his twenty-first birthday and to be adminstered by said trustee as said Court may from time to time decree ....\\u201d The petitioner appealed from that decree. The creation of a trust was dependent upon Roxine\\u2019s intention, manifested by her words and conduct, and the ends to be accomplished. Kerr v. Crane, 212 Mass. 224, 226-228 (1912). Carpenter v. Suffolk Franklin Sav. Bank, 362 Mass. 770, 777-779 (1973). Compare Pouey v.'},
#  {'id': '0868-01.json_chunk_4',
#   'text_chunk': 'fested by her words and conduct, and the ends to be accomplished. Kerr v. Crane, 212 Mass. 224, 226-228 (1912). Carpenter v. Suffolk Franklin Sav. Bank, 362 Mass. 770, 777-779 (1973). Compare Pouey v. Colonial Beacon Oil Co. 294 Mass. 86, 90-91 (1936). The petitioner relies on Olliffe v. Wells, 130 Mass. 221 (1881), Sears v. Choate, 146 Mass. 395 (1888), and Ames v. Hall, 313 Mass. 33 (1943), all of which are distinguishable on their facts. The petitioner\\u2019s brief cites no authority, nor have we found any, supporting his position that on these facts his subsequent appointment as guardian entitles him to take possession of the proceeds to the exclusion of Rose. There was no error.\\nDecree affirmed.", "type": "majority", "author": null}], "attorneys": ["Paul A. Gargano for the petitioner.", "Francis E. Jenney for Rose Hawkes."], "corrections": "", "head_matter": "John R. Prespolis, guardian, vs. Rose Hawkes & another.\\nJanuary 22, 1974.\\nPaul A. Gargano for the petitioner.\\nFrancis E'},
#  {'id': '0868-01.json_chunk_5',
#   'text_chunk': '.", "Francis E. Jenney for Rose Hawkes."], "corrections": "", "head_matter": "John R. Prespolis, guardian, vs. Rose Hawkes & another.\\nJanuary 22, 1974.\\nPaul A. Gargano for the petitioner.\\nFrancis E. Jenney for Rose Hawkes.\\nThe John Hancock Mutual Life Insurance Company. A decree pro confesso was entered against that company for failure to answer. It has not appealed from the final decree."}, "file_name": "0868-01", "first_page_order": 884, "last_page_order": 884}'},
#  {'id': '0869-01.json_chunk_0',
#   'text_chunk': '{"id": 3944593, "name": "Saugus Auto Theatre Corporation vs. Munroe Realty Corp.", "name_abbreviation": "Saugus Auto Theatre Corp. v. Munroe Realty Corp.", "decision_date": "1974-02-04", "docket_number": "", "first_page": "869", "last_page": "869", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 869"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "361 Mass. 131", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3867982], "year": 1972, "pin_cites": [{"page": "137"}], "opinion_index": 0, "case_paths": ["/mass/361/0131-01"]}, {"cite": "336 Mass. 444", "category": "reporters:state", "reporter": "Mass.", "case_ids": [881813], "year": 1972, "pin_cites": [{"page": "447"}], "opinion_index": 0, "case_paths": ["/mass/336/0444-01"]}, {"cite": "327 Mass. 64", "category": "reporters:state", "reporter": "Mass.", "case_id'},
#  {'id': '0869-01.json_chunk_1',
#   'text_chunk': ' [881813], "year": 1972, "pin_cites": [{"page": "447"}], "opinion_index": 0, "case_paths": ["/mass/336/0444-01"]}, {"cite": "327 Mass. 64", "category": "reporters:state", "reporter": "Mass.", "case_ids": [512143], "year": 1972, "pin_cites": [{"page": "67"}], "opinion_index": 0, "case_paths": ["/mass/327/0064-01"]}, {"cite": "176 Mass. 115", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3483094], "year": 1972, "pin_cites": [{"page": "117"}], "opinion_index": 0, "case_paths": ["/mass/176/0115-01"]}, {"cite": "3 Allen 230", "category": "reporters:state", "reporter": "Allen", "case_ids": [2098620], "pin_cites": [{"page": "232"}], "opinion_index": 0, "case_paths": ["/mass/85/0230-01"]}], "analysis": {"cardinality": 235, "char_count": 2841, "ocr_confidence": 0.898, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12149974766868647}, "sha256": "f9cfefc9f6177b004bce92ca22d367ce9a192423f55ec44f7abb6e9ea18ece49", "simhash": "1:e9c5d1f9d86ead99", "word_count": 482}, "l'},
#  {'id': '0869-01.json_chunk_2',
#   'text_chunk': ' {"raw": 4.03580807328026e-08, "percentile": 0.12149974766868647}, "sha256": "f9cfefc9f6177b004bce92ca22d367ce9a192423f55ec44f7abb6e9ea18ece49", "simhash": "1:e9c5d1f9d86ead99", "word_count": 482}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Saugus Auto Theatre Corporation vs. Munroe Realty Corp."], "opinions": [{"text": "This is a bill in equity for declaratory relief brought by the assignee of a twenty-five year commercial lease to determine whether it is entitled to continue in possession of the leased premises for the remainder of a renewal term of twenty-five years to have commenced on May 1, 1963. From a final decree in favor of the plaintiff, the lessor\\u2019s grantee appeals. The ultimate question raised \\u2014 whether the defendant has a present right to enter upon the premises and expel the plaintiff\\u2014 is disposed of by considering the defendan'},
#  {'id': '0869-01.json_chunk_3',
#   'text_chunk': '2019s grantee appeals. The ultimate question raised \\u2014 whether the defendant has a present right to enter upon the premises and expel the plaintiff\\u2014 is disposed of by considering the defendant\\u2019s contention under a provision of the lease which reads, \\u201c... if the premises or any substantial portion thereof are taken by public authority. . . the Lessors ... may ... without further notice or demand, enter into and upon the said premises ... and expel the said Lessee ... and upon entry as aforesaid, this lease shall cease and be ended.\\u201d The judge found that on May 13, 1970, the Commonwealth by eminent domain took 2.15 acres belonging to the defendant, most of which was from the thirteen acres subject to the lease, and made an award (the parties agree) of $129,200 to the defendant. The judge ruled that, as the leased premises could only be used during the term of the lease and any extension or renewal thereof as a drive-in theater, and as the taking did not substantia'},
#  {'id': '0869-01.json_chunk_4',
#   'text_chunk': 'defendant. The judge ruled that, as the leased premises could only be used during the term of the lease and any extension or renewal thereof as a drive-in theater, and as the taking did not substantially affect the capacity or operation thereof, the portion taken was not substantial within the meaning of the lease. A provision such as the one under consideration is commonly inserted in a lease for the purpose of affording the landlord the rights to terminate the lease, evict the tenant, and deprive the tenant of an opportunity to share in the damages (Munigle v. Boston, 3 Allen 230, 232 [1861]; Goodyear Shoe Mach. Co. v. Boston Terminal Co. 176 Mass. 115, 117 [1900]; Sparrow Chisholm Co. v. Boston, 327 Mass. 64, 67 [1951]; Newman v. Commonwealth, 336 Mass. 444, 447 [1957]), rights the landlord would not have in the absence of such a provision. Van Dusen Aircraft Supplies of New England, Inc. v. Massachusetts Port Authy. 361 Mass. 131, 137 (1972), and cases cited. It is in the light of '},
#  {'id': '0869-01.json_chunk_5',
#   'text_chunk': 'lord would not have in the absence of such a provision. Van Dusen Aircraft Supplies of New England, Inc. v. Massachusetts Port Authy. 361 Mass. 131, 137 (1972), and cases cited. It is in the light of such purpose that we must determine whether the portion taken is substantial within the meaning of the lease. \\u201cSubstantial\\u201d means \\u201cof real worth and importance; of considerable value; valuable.\\u201d Black\\u2019s Law Dictionary (rev. 4th ed.). A majority of the panel are of the opinion that the taking of some fifteen percent of the leased premises must be regarded as substantial as that term is used in the lease. The final decree is reversed, and a new final decree is to be entered declaring that the defendant is entitled to enter the premises and to expel the plaintiff.\\nSo ordered.", "type": "majority", "author": null}], "attorneys": ["JohnJ. Jennings for the defendant.", "Joseph E. Iovino for the plaintiff."], "corrections": "", "head_matter": "Saugus Auto Theatre Corpora'},
#  {'id': '0869-01.json_chunk_6',
#   'text_chunk': 'ered.", "type": "majority", "author": null}], "attorneys": ["JohnJ. Jennings for the defendant.", "Joseph E. Iovino for the plaintiff."], "corrections": "", "head_matter": "Saugus Auto Theatre Corporation vs. Munroe Realty Corp.\\nFebruary 4, 1974.\\nJohnJ. Jennings for the defendant.\\nJoseph E. Iovino for the plaintiff."}, "file_name": "0869-01", "first_page_order": 885, "last_page_order": 885}'},
#  {'id': '0869-02.json_chunk_0',
#   'text_chunk': '{"id": 3944099, "name": "Henry A. Mariani vs. Trustees of Tufts College", "name_abbreviation": "Mariani v. Trustees of Tufts College", "decision_date": "1974-02-05", "docket_number": "", "first_page": "869", "last_page": "870", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 869"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "358 Mass. 331", "category": "reporters:state", "reporter": "Mass.", "case_ids": [298375], "year": 1970, "opinion_index": 0, "case_paths": ["/mass/358/0331-01"]}, {"cite": "315 Mass. 416", "category": "reporters:state", "reporter": "Mass.", "case_ids": [904096], "year": 1944, "pin_cites": [{"page": "418-419"}], "opinion_index": 0, "case_paths": ["/mass/315/0416-01"]}, {"cite": "296 Mass. 509", "category": "reporters:state", "reporter": "Mass.", "case_ids": [885003], "year": 1937, "opinion_index": 0, "'},
#  {'id': '0869-02.json_chunk_1',
#   'text_chunk': '19"}], "opinion_index": 0, "case_paths": ["/mass/315/0416-01"]}, {"cite": "296 Mass. 509", "category": "reporters:state", "reporter": "Mass.", "case_ids": [885003], "year": 1937, "opinion_index": 0, "case_paths": ["/mass/296/0509-01"]}, {"cite": "258 Mass. 464", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3821042], "year": 1927, "opinion_index": 0, "case_paths": ["/mass/258/0464-01"]}, {"cite": "168 Mass. 7", "category": "reporters:state", "reporter": "Mass.", "case_ids": [471537], "year": 1897, "opinion_index": 0, "case_paths": ["/mass/168/0007-01"]}, {"cite": "261 Mass. 462", "category": "reporters:state", "reporter": "Mass.", "case_ids": [850110], "year": 1897, "pin_cites": [{"page": "467-468"}], "opinion_index": 0, "case_paths": ["/mass/261/0462-01"]}, {"cite": "194 Mass. 596", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3501815], "pin_cites": [{"page": "600-601"}], "opinion_index": 0, "case_paths": ["/mass/194/0596-01"]}, {"cite": "359 Mas'},
#  {'id': '0869-02.json_chunk_2',
#   'text_chunk': '4 Mass. 596", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3501815], "pin_cites": [{"page": "600-601"}], "opinion_index": 0, "case_paths": ["/mass/194/0596-01"]}, {"cite": "359 Mass. 185", "category": "reporters:state", "reporter": "Mass.", "case_ids": [294541], "pin_cites": [{"page": "187"}], "opinion_index": 0, "case_paths": ["/mass/359/0185-01"]}], "analysis": {"cardinality": 202, "char_count": 2073, "ocr_confidence": 0.91, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12148024846236209}, "sha256": "ec80b02e118e253afc1f8cdf0d1bf7791efc9be076918f76a33f2a0726887054", "simhash": "1:5e56c40b58ce8708", "word_count": 350}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Henry A. Mariani vs. Trustees of Tufts College."], "opinions": [{"text": "By these proceedings, commenced in 1972, the petitioner seeks a writ of mandamus to compel t'},
#  {'id': '0869-02.json_chunk_3',
#   'text_chunk': 'ody": {"judges": [], "parties": ["Henry A. Mariani vs. Trustees of Tufts College."], "opinions": [{"text": "By these proceedings, commenced in 1972, the petitioner seeks a writ of mandamus to compel the respondent (1) to readmit the petitioner as a student in the doctoral program of the respondent\\u2019s graduate school of arts and sciences and (2) to examine the petitioner on a doctoral thesis submitted by him in 1961. The petitioner has appealed from an order sustaining (without leave to amend) the respondent\\u2019s demurrer to the petition. One of the grounds of the demurrer (see Channel Fish Co. Inc. v. Boston Fish Market Corp. 359 Mass. 185, 187 [1971]), is that mandamus does not lie to compel a private institution such as the respondent to perform the acts prayed for in the petition. An examination of the respondent\\u2019s charter (St. 1852, c. 141, as from time to time amended), of which we can and do take judicial notice (American Steel & Wire Co. v. Bearse, 194 Mass. 596, 600-'},
#  {'id': '0869-02.json_chunk_4',
#   'text_chunk': ' An examination of the respondent\\u2019s charter (St. 1852, c. 141, as from time to time amended), of which we can and do take judicial notice (American Steel & Wire Co. v. Bearse, 194 Mass. 596, 600-601 [1907]; Baizen v. Board of Pub. Works of Everett, ante, 602, 604, n. 5 [1973], and cases cited), discloses that the respondent is a private educational corporation in or in the property of which the petitioner has no rights personal to himself (cf. Moustakis v. Hellenic Orthodox Soc. of Salem & Peabody, 261 Mass. 462, 467-468 [1928]). An examination of the petition in this matter discloses, as the petitioner all but admits in his brief, that the rights here sought to be vindicated are purely private and contractual in nature. Compare Curry v. Lasell Seminary Co. 168 Mass. 7 (1897); Hall v. Mount Ida School for Girls, Inc. 258 Mass. 464 (1927); Hood v. Tabor Academy, 296 Mass. 509 (1937). Mandamus does not lie for the vindication of such rights. Parrotta v. Hederson, 315 Mass. 416, 418-'},
#  {'id': '0869-02.json_chunk_5',
#   'text_chunk': ' Mount Ida School for Girls, Inc. 258 Mass. 464 (1927); Hood v. Tabor Academy, 296 Mass. 509 (1937). Mandamus does not lie for the vindication of such rights. Parrotta v. Hederson, 315 Mass. 416, 418-419 (1944).\\nJohnP. Dowcett forthe petitioner.\\nMichael J. Liston for the respondent.\\nOrder sustaining demurrer affirmed.\\nWe are not here concerned with any relationships which the respondent may from time to time have with an agency of government. Contrast Trustees of Tufts College v. Volpe Constr. Co. Inc. 358 Mass. 331 (1970).", "type": "majority", "author": null}], "attorneys": ["JohnP. Dowcett forthe petitioner.", "Michael J. Liston for the respondent."], "corrections": "", "head_matter": "Henry A. Mariani vs. Trustees of Tufts College.\\nFebruary 5, 1974."}, "file_name": "0869-02", "first_page_order": 885, "last_page_order": 886}'},
#  {'id': '0869-02.json_chunk_6',
#   'text_chunk': 'st_page_order": 885, "last_page_order": 886}'},
#  {'id': '0870-01.json_chunk_0',
#   'text_chunk': '{"id": 3944624, "name": "Commonwealth vs. Robert Hickson, Jr.", "name_abbreviation": "Commonwealth v. Hickson", "decision_date": "1974-02-14", "docket_number": "", "first_page": "870", "last_page": "870", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 870"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "364 Mass. 426", "category": "reporters:state", "reporter": "Mass.", "case_ids": [289684], "year": 1973, "opinion_index": 0, "case_paths": ["/mass/364/0426-01"]}], "analysis": {"cardinality": 46, "char_count": 331, "ocr_confidence": 0.931, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12150090603737901}, "sha256": "b54ca81d38470d2cb57e88e3201cb63f09b3fa18438cf5ae4a77f8703d76f5d0", "simhash": "1:073dbbb2e8f46564", "word_count": 53}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": '},
#  {'id': '0870-01.json_chunk_1',
#   'text_chunk': 'b54ca81d38470d2cb57e88e3201cb63f09b3fa18438cf5ae4a77f8703d76f5d0", "simhash": "1:073dbbb2e8f46564", "word_count": 53}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Commonwealth vs. Robert Hickson, Jr."], "opinions": [{"text": "This case was entered and the defendant\\u2019s brief filed prior to the decision of Commonwealth v. Hughes, 364 Mass. 426 (1973). The case is governed in every respect by that decision.\\nExceptions overruled.", "type": "majority", "author": null}], "attorneys": ["William A. Nelson & John F. Palmer for the defendant submitted a brief."], "corrections": "", "head_matter": "Commonwealth vs. Robert Hickson, Jr.\\nFebruary 14, 1974.\\nWilliam A. Nelson & John F. Palmer for the defendant submitted a brief."}, "file_name": "0870-01", "first_page_order": 886, "last_page_order": 886}'},
#  {'id': '0870-01.json_chunk_2',
#   'text_chunk': 'elson & John F. Palmer for the defendant submitted a brief."}, "file_name": "0870-01", "first_page_order": 886, "last_page_order": 886}'},
#  {'id': '0870-02.json_chunk_0',
#   'text_chunk': '{"id": 3944110, "name": "Clark W. Wilson vs. Boston Redevelopment Authority & others", "name_abbreviation": "Wilson v. Boston Redevelopment Authority", "decision_date": "1974-02-15", "docket_number": "", "first_page": "870", "last_page": "871", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 870"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "364 Mass. 669", "category": "reporters:state", "reporter": "Mass.", "case_ids": [289719], "year": 1974, "opinion_index": 0, "case_paths": ["/mass/364/0669-01"]}, {"cite": "340 Mass. 73", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3852278], "year": 1959, "pin_cites": [{"page": "77-78"}], "opinion_index": 0, "case_paths": ["/mass/340/0073-01"]}, {"cite": "227 Mass. 405", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3451042], "year": 1917, "opin'},
#  {'id': '0870-02.json_chunk_1',
# ...
#  {'id': '0878-01.json_chunk_1',
#   'text_chunk': '": 1960, "pin_cites": [{"page": "662"}], "opinion_index": 0, "case_paths": ["/mass/340/0660-01"]}, {"cite": "336 Mass. 497", "category": "reporters:state", "reporter": "Mass.", "case_ids": [881855], "year": 1957, "pin_cites": [{"page": "500", "parenthetical": "decided under an identical provision of Rule 90 of the Superior Court [1954J"}], "opinion_index": 0, "case_paths": ["/mass/336/0497-01"]}, {"cite": "357 Mass. 306", "category": "reporters:state", "reporter": "Mass.", "case_ids": [295986], "year": 1970, "pin_cites": [{"page": "318"}], "opinion_index": 0, "case_paths": ["/mass/357/0306-01"]}], "analysis": {"cardinality": 252, "char_count": 3130, "ocr_confidence": 0.898, "pagerank": {"raw": 6.5754854646575e-08, "percentile": 0.4026889212459877}, "sha256": "71c37d0f7036011e76fc7b18c0d56d8e77f861082a5990b4d523d504e97dc192", "simhash": "1:b35b353b20ec04f3", "word_count": 492}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harv'},
#  {'id': '0878-01.json_chunk_2',
#   'text_chunk': '8e77f861082a5990b4d523d504e97dc192", "simhash": "1:b35b353b20ec04f3", "word_count": 492}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Julia I. Paone, temporary conservator, vs. Norman W. Rogers & another."], "opinions": [{"text": "The respondents appeal from a final decree in equity of a Probate Court setting aside a conveyance of real estate, made without consideration, by the petitioner\\u2019s ward to the respondents by reason of the ward\\u2019s mental incompetence. They also appeal from an interlocutory decree confirming the report of the master to whom the case was referred, to which they had filed objections, and from four other contemporaneously entered interlocutory decrees. We perceive no error. (1) Some of the respondents\\u2019 objections are based on their contention that the petition alleged fraud and undue influence as the sole grounds for settin'},
#  {'id': '0878-01.json_chunk_3',
#   'text_chunk': 'terlocutory decrees. We perceive no error. (1) Some of the respondents\\u2019 objections are based on their contention that the petition alleged fraud and undue influence as the sole grounds for setting aside the conveyance, that the master\\u2019s finding of no such fraud or undue influence required dismissal of the petition, and that the issue of mental incompetence was not before him. This is the principal contention underlying the respondents\\u2019 appeals from decrees denying their motion to strike the master\\u2019s finding of mental incompetence, denying their motion to dismiss the petition, allowing a subsequent motion to amend the petition, and confirming the master\\u2019s report. Our examination of the petition and answer \\u2014 which respectively allege and deny that the ward was \\u201cmentally incompetent\\u201d and \\u201cincapable of understanding her property rights\\u201d when she executed the deed \\u2014 persuades us that her competence was at issue from the outset. The chal'},
#  {'id': '0878-01.json_chunk_4',
#   'text_chunk': 'u201cmentally incompetent\\u201d and \\u201cincapable of understanding her property rights\\u201d when she executed the deed \\u2014 persuades us that her competence was at issue from the outset. The challenged finding was therefore well within the scope of the pleadings, and the motion to amend the petition (which insofar as material merely added further allegations of such incompetence) was properly allowed. See Alpert v. Commonwealth, 357 Mass. 306, 318 (1970). (2) It follows that the respondents\\u2019 motion to recommit, for the stated purpose of permitting their introduction of evidence to refute the allegation of mental incompetence, was correctly denied. (3) The remaining objections assert that the master\\u2019s finding of mental incompetence was unsupported by evidence. Since no transcript appears to have been taken by a stenographer selected or approved by the master and no summary of evidence could therefore have been obtained in accordance with Rule 24 of the Probate Courts (195'},
#  {'id': '0878-01.json_chunk_5',
#   'text_chunk': 'ript appears to have been taken by a stenographer selected or approved by the master and no summary of evidence could therefore have been obtained in accordance with Rule 24 of the Probate Courts (1959), these objections have no standing. DiMare v. Capaldi, 336 Mass. 497, 500 (1957) (decided under an identical provision of Rule 90 of the Superior Court [1954J). (4) Nor is there any merit in the assertion that the language in which the master\\u2019s finding is couched \\u2014 the ward \\u201cdid not have sufficient mental competence or capacity to understand or be fully aware of what she was signing\\u201d \\u2014 was insufficient. Except for the words \\u201cor be fully aware of\\u2019 (which we regard as surplusage), the terms of the finding adequately convey the concept of mental incompetence as defined by the Supreme Judicial Court. See Meserve v. Jordan Marsh Co. 340 Mass. 660, 662 (1960). Compare Smith v. Smith, 222 Mass. 102, 107-108 (1915).\\nSamuel Smolensky for the respondents.\\nHarr'},
#  {'id': '0878-01.json_chunk_6',
#   'text_chunk': 'as defined by the Supreme Judicial Court. See Meserve v. Jordan Marsh Co. 340 Mass. 660, 662 (1960). Compare Smith v. Smith, 222 Mass. 102, 107-108 (1915).\\nSamuel Smolensky for the respondents.\\nHarry J. O \\u2019Sullivan for the petitioner.\\nInterlocutory decrees affirmed.\\nFinal decree affirmed with costs of appeal.", "type": "majority", "author": null}], "attorneys": ["Samuel Smolensky for the respondents.", "Harry J. O \\u2019Sullivan for the petitioner."], "corrections": "", "head_matter": "Julia I. Paone, temporary conservator, vs. Norman W. Rogers & another.\\nFebruary 25, 1974."}, "file_name": "0878-01", "first_page_order": 894, "last_page_order": 895}'},
#  {'id': '0879-01.json_chunk_0',
#   'text_chunk': '{"id": 3943308, "name": "William Herbits vs. High-Speed Process Printing Corporation & others", "name_abbreviation": "Herbits v. High-Speed Process Printing Corp.", "decision_date": "1974-02-25", "docket_number": "", "first_page": "879", "last_page": "879", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 879"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "361 Mass. 892", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3869556, 3867469], "year": 1972, "opinion_index": 0, "case_paths": ["/mass/361/0892-01", "/mass/361/0892-02"]}, {"cite": "297 Mass. 219", "category": "reporters:state", "reporter": "Mass.", "case_ids": [886340], "year": 1937, "opinion_index": 0, "case_paths": ["/mass/297/0219-01"]}, {"cite": "272 Mass. 56", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3826911], "year": 19'},
#  {'id': '0879-01.json_chunk_1',
#   'text_chunk': 'e_ids": [886340], "year": 1937, "opinion_index": 0, "case_paths": ["/mass/297/0219-01"]}, {"cite": "272 Mass. 56", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3826911], "year": 1930, "pin_cites": [{"page": "59"}], "opinion_index": 0, "case_paths": ["/mass/272/0056-01"]}, {"cite": "347 Mass. 774", "category": "reporters:state", "reporter": "Mass.", "case_ids": [3860681, 3860060, 3858745], "year": 1964, "opinion_index": 0, "case_paths": ["/mass/347/0774-01", "/mass/347/0774-03", "/mass/347/0774-02"]}, {"cite": "358 Mass. 817", "category": "reporters:state", "reporter": "Mass.", "case_ids": [298449, 298469], "year": 1964, "opinion_index": 0, "case_paths": ["/mass/358/0817-01", "/mass/358/0817-02"]}], "analysis": {"cardinality": 160, "char_count": 1734, "ocr_confidence": 0.908, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12144723495462477}, "sha256": "55185740eab365b0b2c7aab7e40553fc35b280e1756ac1294f56a10367f9d8d2", "simhash": "1:a7cc3baeb68c359e", "word'},
#  {'id': '0879-01.json_chunk_2',
#   'text_chunk': '.908, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12144723495462477}, "sha256": "55185740eab365b0b2c7aab7e40553fc35b280e1756ac1294f56a10367f9d8d2", "simhash": "1:a7cc3baeb68c359e", "word_count": 274}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["William Herbits vs. High-Speed Process Printing Corporation & others."], "opinions": [{"text": "This bill in equity, brought by a minority stockholder of the defendant High-Speed Process Printing Corporation (High-Speed) alleging various wrongs committed against High-Speed by its remaining stockholders and directors and by other defendants, was filed in the Superior Court on July 27, 1972. The plaintiff appeals from an interlocutory decree sustaining the defendants\\u2019 plea and from a final decree dismissing the bill. The plea asserted the defense of res judicata, alleging that after the Superior Court'},
#  {'id': '0879-01.json_chunk_3',
#   'text_chunk': 'als from an interlocutory decree sustaining the defendants\\u2019 plea and from a final decree dismissing the bill. The plea asserted the defense of res judicata, alleging that after the Superior Court had entered a decree after rescript (Herbits v. High-Speed Process Printing Corp. 358 Mass. 817 [1971]) for the same plaintiff, he brought \\u201ca Petition for Contempt and a Petition for Enforcement of the final decree against the defendants,\\u201d which were respectively dismissed and denied by the Superior Court after hearing on June 9, 1972. SeeSt. Martin v. Spinner, 347 Mass. 774 (1964). In the present case the evidence is not reported, no report of material facts was requested and no findings of fact were made by the Superior Court judge. The only question presented upon the record before us is whether the final decree falls within the scope of the pleadings. The entry of that decree imports that the judge found every necessary fact required to support such entry. Abeloff v. Peacard'},
#  {'id': '0879-01.json_chunk_4',
#   'text_chunk': 're us is whether the final decree falls within the scope of the pleadings. The entry of that decree imports that the judge found every necessary fact required to support such entry. Abeloff v. Peacard, 272 Mass. 56, 59 (1930). Commissioner of Ins. v. Commonwealth Mut. Liab. Ins. Co. 297 Mass. 219 (1937). Albano v. North Adams Hoosac Sav. Bank, 361 Mass. 892 (1972).\\nInterlocutory decree affirmed.\\nFinal decree affirmed with costs of appeal.", "type": "majority", "author": null}], "attorneys": ["Donald N. Sweeney for the plaintiff.", "JohnF. McGarry (Vincent F. Stulgis with him) for the defendants."], "corrections": "", "head_matter": "William Herbits vs. High-Speed Process Printing Corporation & others.\\nFebruary 25, 1974.\\nDonald N. Sweeney for the plaintiff.\\nJohnF. McGarry (Vincent F. Stulgis with him) for the defendants."}, "file_name": "0879-01", "first_page_order": 895, "last_page_order": 895}'},
#  {'id': '0879-01.json_chunk_5',
#   'text_chunk': 'tulgis with him) for the defendants."}, "file_name": "0879-01", "first_page_order": 895, "last_page_order": 895}'},
#  {'id': '0879-02.json_chunk_0',
#   'text_chunk': '{"id": 3944762, "name": "Home Carpet Cleaning Company, Inc. vs. Henry Baker & another", "name_abbreviation": "Home Carpet Cleaning Co. v. Baker", "decision_date": "1974-02-27", "docket_number": "", "first_page": "879", "last_page": "880", "citations": [{"type": "official", "cite": "1 Mass. App. Ct. 879"}], "court": {"name_abbreviation": "Mass. App. Ct.", "id": 8980, "name": "Massachusetts Appeals Court"}, "jurisdiction": {"id": 4, "name_long": "Massachusetts", "name": "Mass."}, "cites_to": [{"cite": "237 Mass. 118", "category": "reporters:state", "reporter": "Mass.", "case_ids": [60215], "year": 1921, "pin_cites": [{"page": "121"}], "opinion_index": 0, "case_paths": ["/mass/237/0118-01"]}], "analysis": {"cardinality": 143, "char_count": 1865, "ocr_confidence": 0.889, "pagerank": {"raw": 4.03580807328026e-08, "percentile": 0.12150785624953424}, "sha256": "57e4fffd0d388699359a3d4dfde527400dec8f10b96b440771f207006452cba3", "simhash": "1:8b41a057132a0da5", "word_count": 308}, "last_updated'},
#  {'id': '0879-02.json_chunk_1',
#   'text_chunk': '03580807328026e-08, "percentile": 0.12150785624953424}, "sha256": "57e4fffd0d388699359a3d4dfde527400dec8f10b96b440771f207006452cba3", "simhash": "1:8b41a057132a0da5", "word_count": 308}, "last_updated": "2024-02-27T15:55:54.369989+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "casebody": {"judges": [], "parties": ["Home Carpet Cleaning Company, Inc. vs. Henry Baker & another."], "opinions": [{"text": "Home Carpet Cleaning Company, Inc. (Home), brought this action of contract with counts on an express contract and in quantum meruit to recover for services performed and material supplied to Henry Baker (Baker) for cleaning, repairing and replacing rugs damaged by the bursting of a hot water pipe in Baker\\u2019s apartment. Identical counts were brought against Liberty Mutual Insurance Company (Liberty), the insurer of the installer of the pipe. The District Court judge found for the plaintiff against each defendant on the counts in quantum merui'},
#  {'id': '0879-02.json_chunk_2',
#   'text_chunk': 'ght against Liberty Mutual Insurance Company (Liberty), the insurer of the installer of the pipe. The District Court judge found for the plaintiff against each defendant on the counts in quantum meruit and found for the defendants on the the counts on express contract. The Appellate Division affirmed the finding against Baker, reversed the finding against Liberty and ordered entry of judgment for the latter. No appeal was taken by Home from the order with respect to Liberty; so only Baker\\u2019s appeal from the finding against him is before us. (The appeal was transferred to us under G. L. c. 211A, \\u00a7 12.) In order to recover in quantum meruit it must appear that the work was performed under circumstances warranting a finding that the plaintiff expected that the defendant would pay for the work, that the defendant acted with that expectation and that the defendant allowed the plaintiff so to act without objection. Albert v. Boston Mortgage Bond Co. 237 Mass. 118, 121 (1921). From a'},
#  {'id': '0879-02.json_chunk_3',
#   'text_chunk': ' the work, that the defendant acted with that expectation and that the defendant allowed the plaintiff so to act without objection. Albert v. Boston Mortgage Bond Co. 237 Mass. 118, 121 (1921). From a review of the evidence, including exhibits, contained in the judge\\u2019s consolidated report to the Appellate Division, we are satisfied that the evidence did not, as matter of law, warrant a finding for Home. Treating the order of the Appellate Division as a dismissal of the report, that order is reversed. The finding for the plaintiff is vacated and judgment is to be entered for the defendant Baker.\\nWilliam B. Baker for Henry Baker.\\nSo ordered.", "type": "majority", "author": null}], "attorneys": ["William B. Baker for Henry Baker."], "corrections": "", "head_matter": "Home Carpet Cleaning Company, Inc. vs. Henry Baker & another.\\nFebruary 27, 1974."}, "file_name": "0879-02", "first_page_order": 895, "last_page_order": 896}'},
#  {'id': '0879-02.json_chunk_4',
#   'text_chunk': 'ng Company, Inc. vs. Henry Baker & another.\\nFebruary 27, 1974."}, "file_name": "0879-02", "first_page_order": 895, "last_page_order": 896}'}]
